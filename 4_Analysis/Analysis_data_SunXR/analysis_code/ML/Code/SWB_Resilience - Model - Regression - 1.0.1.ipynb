# %% [markdown]
# **Version: 1.0.1**
#
# If you encounter any errors, please contact me. I will complete the verification and make corrections as soon as possible.

# %% [markdown]
# # Usage Guide
#
# This code consists of three sections: AutoML, Interpretability Analysis, and Exploratory Factor Analysis (EFA).
# When using this code, please remember to cite this article.
# Each section includes detailed comments, so please modify the respective variables according to the comments to complete your research.
#
# 0. **Preoaration**
# 1. **AutoML**: Utilize AutoML tools for model training and optimization.
# 2. **Interpretability Analysis**: Use tools like SHAP for model interpretability analysis to identify important features and their relationships.
# 3. **Exploratory Factor Analysis (EFA)**: Conduct EFA to uncover the underlying factor structure in the data.
#
# Please adjust the respective variables and parameters according to your specific needs to fit your research data and objectives.

# %% [markdown]
# # 0 Preparation
#
# In this section, you need to import the necessary libraries for the code to function correctly. Ensure that each library is successfully imported before proceeding with further steps.

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from autogluon.tabular import TabularDataset, TabularPredictor
from scipy import stats
import shap
import matplotlib.pyplot as plt
from factor_analyzer import FactorAnalyzer, calculate_bartlett_sphericity, calculate_kmo, Rotator
from sklearn.decomposition import PCA

# %% [markdown]
# ## 0.1 Data Import
# **Feature Engineering**
#
# In this section, you need to import your data and ensure it is converted into a tabular format, with the first row containing the column names. Modify the file path to the CSV file that contains your data.

# %%
# Modify the file path to point to your CSV data file
# Load the data into a pandas DataFrame
file_path = '/Users/sunxinru/Desktop/ML/Data/ML_pre.csv'
data=pd.read_csv(file_path,header=0) 
# Display the first few rows of the data to verify successful import
print(data.head())
# Out:
#    selfclarity_1  selfclarity_2  selfclarity_3  selfclarity_4  selfclarity_5  \
# 0       0.314527      -0.326269       0.760821      -0.859175       0.492151
# 1       0.314527       0.458962      -0.906687      -0.032856       0.492151
# 2       1.369240       0.458962       0.760821       1.619782       1.322862
# 3       0.314527       1.244192       1.594575       0.793463       1.322862
# 4      -0.740186      -1.896730      -0.906687      -1.685493      -1.999982
#
#    selfclarity_6  selfclarity_7  selfclarity_8  selfclarity_9  selfclarity_10  \
# 0       0.306556       0.413315       0.345348       0.381702       -0.837878
# 1       0.306556       0.413315       0.345348      -0.425004        0.764603
# 2       0.306556       0.413315       1.145854       1.188408        0.764603
# 3       0.306556       1.283179       0.345348       1.188408        1.565844
# 4      -1.683093      -0.456549      -1.255664      -1.231711       -0.837878
#
#    ...  moral_ALT_rt  ability_ALT_d  ability_SRET_EW  moral_SRET_EW  \
# 0  ...     -1.109253       1.185451         0.764175       0.648044
# 1  ...     -0.804771      -0.145036         0.764175       0.214579
# 2  ...     -0.964879       1.332234         1.038928       0.214579
# 3  ...     -0.655354      -0.189948        -0.060085      -1.085819
# 4  ...      0.365202       0.624957        -0.884345       0.648044
#
#    ability_SRET_rt  moral_SRET_rt  SGPS  gad  phq  SWB
# 0        -0.144987      -0.215157    13    7    7   29
# 1         0.519029      -1.253541    15    4    6   30
# 2        -4.720479      -2.142863    20    7    9   23
# 3        -0.331964       0.082375     9    0    0   28
# 4         0.384222       0.534325     9    0    0   29
#
# [5 rows x 144 columns]

# %% [markdown]
# ## 0.2 Data Selection
#
# In psychological research, not all features are necessarily included in the analysis.
# Therefore, after `data.iloc`, input all the variables you wish to include (including the dependent variable).
# Modify the line `target = data['CD-RISC']` by replacing `CD-RISC` with the name of your dependent variable as it appears in your CSV file.

# %%
# Modify with the columns you need
#features = data.iloc[:, 1:44]

# Modify 'CD-RISC' to the name of your dependent variable
#target = data['CD-RISC']

#data = pd.concat([features, target], axis=1)
#for column in data.columns:
    #if pd.api.types.is_numeric_dtype(data[column]):
        #data[column] = data[column].astype('float')

# %%
# 取出前 140 列作为特征
features = data.iloc[:, 0:140]   # 取前 140 列（即第 1 列到第 140 列，对应索引 0 到 139）

# 取第 144 列作为目标变量（列名是 'SWB'）
target = data.iloc[:, 143]       # 这是第141列
# 合并成新的数据集
data_SWB = pd.concat([features, target], axis=1)

# 确保所有数值列转换为 float 类型
for column in data_SWB.columns:
    if pd.api.types.is_numeric_dtype(data_SWB[column]):
        data_SWB[column] = data_SWB[column].astype('float')

# %% [markdown]
# ## 0.3 Handling Anomalies
# To facilitate checking for anomalies in the data, count the unique values in each column.
# For example, we can see an anomaly in the "Age" column. There is an erroneous value: `Value: 2.0, Count: 1`, where the age was mistakenly entered as 2.
# You can follow this example to modify and handle the anomalies in your data. Adjust the variable name and the range according to your needs.

# %%
# Count unique values in each column to check for anomalies
for column in data_SWB.columns:
    print(f"Column: {column}")
    value_counts = data_SWB[column].value_counts(dropna=False)
    for value, count in value_counts.items():
        print(f"Value: {value}, Count: {count}")
    print("\n")
# Out:
# Column: selfclarity_1
# Value: 0.314526814129491, Count: 254
# Value: 1.36924006417705, Count: 90
# Value: -0.740186435918068, Count: 80
# Value: -1.79489968596563, Count: 77
# Value: -2.84961293601319, Count: 2
#
#
# Column: selfclarity_2
# Value: 0.458961839689885, Count: 166
# Value: 1.24419247017972, Count: 116
# Value: -1.11149942128979, Count: 107
# Value: -0.326268790799952, Count: 73
# Value: -1.89673005177963, Count: 41
#
#
# Column: selfclarity_3
# Value: -0.906686528943575, Count: 160
# Value: 0.760821054451739, Count: 122
# Value: -0.0729327372459181, Count: 110
# Value: 1.5945748461494, Count: 76
# Value: -1.74044032064123, Count: 35
#
#
# Column: selfclarity_4
# Value: -0.859174549653067, Count: 184
# Value: 0.793463303025681, Count: 120
# Value: -0.0328556233136928, Count: 91
# Value: 1.61978222936506, Count: 75
# Value: -1.68549347599244, Count: 33
#
#
# Column: selfclarity_5
# Value: 0.492150779997121, Count: 176
# Value: -1.1692709806643, Count: 115
# Value: 1.32286166032783, Count: 101
# Value: -0.33856010033359, Count: 82
# Value: -1.99998186099501, Count: 29
#
#
# Column: selfclarity_6
# Value: 0.306556330305246, Count: 260
# Value: 1.30138106671517, Count: 94
# Value: -1.68309314251461, Count: 88
# Value: -0.688268406104682, Count: 55
# Value: -2.67791787892454, Count: 6
#
#
# Column: selfclarity_7
# Value: 0.4133149900547, Count: 195
# Value: -1.32641254130525, Count: 111
# Value: 1.28317875573467, Count: 107
# Value: -0.456548775625275, Count: 73
# Value: -2.19627630698522, Count: 17
# Value: 25.0, Count: 27
# Value: 28.0, Count: 27
# Value: 30.0, Count: 26
# Value: 24.0, Count: 25
# Value: 17.0, Count: 25
# Value: 26.0, Count: 25
# Value: 29.0, Count: 25
# Value: 15.0, Count: 22
# Value: 35.0, Count: 22
# Value: 14.0, Count: 21
# Value: 20.0, Count: 21
# Value: 19.0, Count: 21
# Value: 22.0, Count: 21
# Value: 16.0, Count: 17
# Value: 13.0, Count: 17
# Value: 23.0, Count: 16
# Value: 12.0, Count: 15
# Value: 21.0, Count: 15
# Value: 11.0, Count: 14
# Value: 32.0, Count: 13
# Value: 18.0, Count: 11
# Value: 10.0, Count: 10
# Value: 34.0, Count: 9
# Value: 31.0, Count: 9
# Value: 33.0, Count: 6
# Value: 7.0, Count: 5
# Value: 6.0, Count: 4
# Value: 9.0, Count: 4
# Value: 5.0, Count: 1
# Value: 8.0, Count: 1

# %%
#To address anomalies, replace values in the "Age" column that are less than 18 or greater than 24 with null values.
#data.loc[(data['Age'] < 18) | (data['Age'] > 24), 'Age'] = np.nan

# %%
# View Missing Value Proportions
null_ratio = data_SWB.isnull().mean()
print(null_ratio)
# Out:
# selfclarity_1      0.0
# selfclarity_2      0.0
# selfclarity_3      0.0
# selfclarity_4      0.0
# selfclarity_5      0.0
#                   ...
# ability_SRET_EW    0.0
# moral_SRET_EW      0.0
# ability_SRET_rt    0.0
# moral_SRET_rt      0.0
# SWB                0.0
# Length: 141, dtype: float64

# %%
# Filling Missing Values with Mean
# data.fillna(data.mean(), inplace=True)
# Filling Missing Values with Median
# data.fillna(data.median(), inplace=True)
# Filling Missing Values with Mode
data.fillna(data_SWB.mode().iloc[0], inplace=True)

# %% [markdown]
# ## 0.4 Data Standardization or Normalization
#
# In this section, you will standardize or normalize the selected columns in your dataset.
# Standardization transforms the data to have a mean of 0 and a standard deviation of 1.
# Normalization scales the data to a range between 0 and 1.

# %%
# Extract the columns to be standardized
#columns_to_scale = ['Age'] + list(data.columns[6:43])
# Initialize the StandardScaler
#scaler = StandardScaler()
#data[columns_to_scale] = scaler.fit_transform(data[columns_to_scale])
# Initialize the MinMaxScaler
# min_max_scaler = MinMaxScaler()
# data[columns_to_scale] = min_max_scaler.fit_transform(data[columns_to_scale])

# %%
# 拆分数据
features_1_140 = data_SWB.iloc[:, 0:140]      # 前 140 列（已标准化）
features_141_144 = data_SWB.iloc[:, 140:144]  # 第 141–144 列（需要标准化）

# 初始化 StandardScaler
scaler = StandardScaler()

# 标准化 141–144 列
features_141_144_scaled = pd.DataFrame(
    scaler.fit_transform(features_141_144),
    columns=features_141_144.columns,  # 保留原始列名
    index=features_141_144.index
)

# 合并：前 140 列 + 标准化后的 141–144 列
data_SWB = pd.concat([features_1_140, features_141_144_scaled], axis=1)

# 看前几行检查
display(data_SWB.head())
# Out:
#    selfclarity_1  selfclarity_2  selfclarity_3  selfclarity_4  selfclarity_5  \
# 0       0.314527      -0.326269       0.760821      -0.859175       0.492151
# 1       0.314527       0.458962      -0.906687      -0.032856       0.492151
# 2       1.369240       0.458962       0.760821       1.619782       1.322862
# 3       0.314527       1.244192       1.594575       0.793463       1.322862
# 4      -0.740186      -1.896730      -0.906687      -1.685493      -1.999982
#
#    selfclarity_6  selfclarity_7  selfclarity_8  selfclarity_9  selfclarity_10  \
# 0       0.306556       0.413315       0.345348       0.381702       -0.837878
# 1       0.306556       0.413315       0.345348      -0.425004        0.764603
# 2       0.306556       0.413315       1.145854       1.188408        0.764603
# 3       0.306556       1.283179       0.345348       1.188408        1.565844
# 4      -1.683093      -0.456549      -1.255664      -1.231711       -0.837878
#
#    ...    Social     Moral  ability_ALT_rt  moral_ALT_rt  ability_ALT_d  \
# 0  ... -0.394679  0.439821        0.375255     -1.109253       1.185451
# 1  ...  0.813375 -0.111875       -1.115250     -0.804771      -0.145036
# 2  ...  1.216060  0.991517        1.265446     -0.964879       1.332234
# 3  ...  1.216060  1.543214        0.110588     -0.655354      -0.189948
# 4  ... -1.602734  0.991517       -0.726022      0.365202       0.624957
#
#    ability_SRET_EW  moral_SRET_EW  ability_SRET_rt  moral_SRET_rt       SWB
# 0         0.764175       0.648044        -0.144987      -0.215157  0.939186
# 1         0.764175       0.214579         0.519029      -1.253541  1.076915
# 2         1.038928       0.214579        -4.720479      -2.142863  0.112812
# 3        -0.060085      -1.085819        -0.331964       0.082375  0.801457
# 4        -0.884345       0.648044         0.384222       0.534325  0.939186
#
# [5 rows x 141 columns]

# %% [markdown]
# ## 0.5 Encoding Categorical Variables
#
# Psychological research often involves many categorical variables. We can handle these by applying one-hot encoding to convert them into a format suitable for machine learning algorithms.

# %%
# List of categorical columns to be encoded
# Replace with your categorical columns
#columns_to_encode = ['Gender','Grade', 'Major', 'Only child', 'Residence']
# Initialize the OneHotEncoder
#encoder = OneHotEncoder(sparse_output=False)
# Fit and transform the categorical features
#encoded_features = encoder.fit_transform(data[columns_to_encode])
# Convert encoded features to a DataFrame
#encoded_columns = encoder.get_feature_names_out(columns_to_encode)
# Reset index to match the original DataFrame
#encoded_df = pd.DataFrame(encoded_features, columns=encoded_columns, index=data.index)

# Drop the original categorical columns from the data
#data.drop(columns=columns_to_encode, inplace=True)
#data = pd.concat([data, encoded_df], axis=1)
#data.head()

# %% [markdown]
# # 1. AutoML Section
#
# In this section, we will use AutoML tools to train and optimize machine learning models. AutoML simplifies the process of model selection, hyperparameter tuning, and performance evaluation.
#
# This section will guide you through splitting your data, training a machine learning model using AutoGluon, and evaluating its performance on the test set. AutoGluon handles many of the complexities of model training and tuning, making it easier to achieve high-quality results with minimal effort. Adjust the split ratio (frac=0.8) and the evaluation metric (eval_metric='accuracy') based on your specific needs.

# %%
# Load Data
data_SWB = TabularDataset(data_SWB)

# %%
# Split data into training and testing sets
#train_data = data.sample(frac=0.8, random_state=42)  # 80% for training, adjust frac as needed
#test_data = data.drop(train_data.index)  # 20% for testing
#train_data.head()
#label = 'CD-RISC'
#train_data[label].describe()

# %%
# 按 80/20 拆分训练集和测试集
train_data = data_SWB.sample(frac=0.8, random_state=42)
test_data = data_SWB.drop(train_data.index)
# 目标变量（待预测的变量）

label = 'SWB' 
# 查看训练集前几行
print(train_data.head())

# 检查目标变量的分布情况
print(train_data[label].describe())
# Out:
#      selfclarity_1  selfclarity_2  selfclarity_3  selfclarity_4  \
# 268       0.314527       0.458962       0.760821      -0.032856
# 73        0.314527      -0.326269       1.594575      -0.032856
# 289       1.369240       0.458962      -0.072933       0.793463
# 155      -1.794900      -1.896730      -0.906687      -0.859175
# 104       0.314527       1.244192       1.594575       0.793463
#
#      selfclarity_5  selfclarity_6  selfclarity_7  selfclarity_8  \
# 268       0.492151       0.306556      -0.456549       0.345348
# 73       -1.169271       0.306556       0.413315      -0.455158
# 289       0.492151       0.306556       0.413315       0.345348
# 155      -1.999982      -1.683093      -1.326413      -2.056170
# 104       1.322862       0.306556       1.283179       1.145854
#
#      selfclarity_9  selfclarity_10  ...    Social     Moral  ability_ALT_rt  \
# 268      -0.425004       -0.837878  ...  0.813375 -0.111875        0.055784
# 73       -1.231711        1.565844  ... -1.200049 -0.111875       -0.118096
# 289       0.381702        1.565844  ...  0.813375  0.991517       -0.932334
# 155      -1.231711       -1.639118  ... -0.394679 -0.111875       -1.452860
# 104       0.381702        1.565844  ...  0.008006 -0.111875       -0.573470
#
#      moral_ALT_rt  ability_ALT_d  ability_SRET_EW  moral_SRET_EW  \
# 268      3.472267       0.054921         0.764175       0.214579
# 73       2.622722       0.329820        -0.334838       0.648044
# 289     -1.688216      -0.912874         0.214668       0.214579
# 155      0.191061      -1.841509        -0.060085       0.648044
# 104      0.871062       1.175379         0.214668       0.214579
#
#      ability_SRET_rt  moral_SRET_rt       SWB
# 268         0.100002      -0.091383 -1.539937
# 73         -0.444233       0.155568 -0.024917
# 289         0.298583      -0.533714 -0.300375
# 155         0.338730      -0.211289 -0.851292
# 104        -0.483882      -0.425214 -1.264479
#
# [5 rows x 141 columns]
# count    402.000000
# mean       0.014483
# std        1.014947
# min       -2.366311
# 25%       -0.816859
# 50%        0.112812
# 75%        0.801457
# max        1.765561
# Name: SWB, dtype: float64

# %% [markdown]
# ## 1.1 Training the Model
# Use AutoGluon to train a model on the training data. Adjust the evaluation metric (eval_metric) as needed, such as f1, recall, roc_auc, etc.

# %%
# Training the Model.Use AutoGluon to train a model on the training data.
#presets='best_quality'   : Maximize accuracy. Default time_limit=3600.
#presets='high_quality'   : Strong accuracy with fast inference speed. Default time_limit=3600.
#presets='good_quality'   : Good accuracy with very fast inference speed. Default time_limit=3600.
#presets='medium_quality' : Fast training time, ideal for initial prototyping.
#save_path = 'agModels-predictClass'
# Train the model using AutoGluon
#predictor = TabularPredictor(label='CD-RISC').fit(train_data, presets='best_quality',auto_stack=True)
# Display a summary of the training process
#predictor.fit_summary()

# %%
# 保存模型的路径
save_path = 'agModels-predictSWB'

# 目标变量
label = 'SWB'

# 训练 AutoGluon 模型
predictor = TabularPredictor(
    label=label,
    path=save_path
).fit(
    train_data,
    presets='best_quality',  
    auto_stack=True
)

# 显示训练过程总结
predictor.fit_summary()
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="agModels-predictSWB"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.4.0
# Python Version:     3.12.7
# Operating System:   Darwin
# Platform Machine:   arm64
# Platform Version:   Darwin Kernel Version 24.5.0: Tue Apr 22 19:54:33 PDT 2025; root:xnu-11417.121.6~2/RELEASE_ARM64_T8122
# CPU Count:          8
# Memory Avail:       3.26 GB / 16.00 GB (20.4%)
# Disk Space Avail:   661.36 GB / 926.35 GB (71.4%)
# ===================================================
# Presets specified: ['best_quality']
# Using hyperparameters preset: hyperparameters='zeroshot'
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 900s of the 3600s of remaining time (25%).
# 2025-09-14 16:14:39,128	INFO util.py:154 -- Outdated packages:
#   ipywidgets==7.8.1 found, needs ipywidgets>=8
# Run `pip install -U ipywidgets`, then restart the notebook server for rich notebook output.
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2025-09-14 16:14:43,303	INFO worker.py:1843 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8266
# 		Context path: "/Users/sunxinru/Desktop/ML/Code/agModels-predictSWB/ds_sub_fit/sub_fit_ho"
# (_dystack pid=93579) Running DyStack sub-fit ...
# (_dystack pid=93579) Beginning AutoGluon training ... Time limit = 892s
# (_dystack pid=93579) AutoGluon will save models to "/Users/sunxinru/Desktop/ML/Code/agModels-predictSWB/ds_sub_fit/sub_fit_ho"
# (_dystack pid=93579) Train Data Rows:    357
# (_dystack pid=93579) Train Data Columns: 140
# (_dystack pid=93579) Label Column:       SWB
# (_dystack pid=93579) Problem Type:       regression
# (_dystack pid=93579) Preprocessing data ...
# (_dystack pid=93579) Using Feature Generators to preprocess the data ...
# (_dystack pid=93579) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=93579) 	Available Memory:                    2702.33 MB
# (_dystack pid=93579) 	Train Data (Original)  Memory Usage: 0.38 MB (0.0% of available memory)
# (_dystack pid=93579) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=93579) 	Stage 1 Generators:
# (_dystack pid=93579) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=93579) 			Note: Converting 13 features to boolean dtype as they only contain 2 unique values.
# (_dystack pid=93579) 	Stage 2 Generators:
# (_dystack pid=93579) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=93579) 	Stage 3 Generators:
# (_dystack pid=93579) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=93579) 	Stage 4 Generators:
# (_dystack pid=93579) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=93579) 	Stage 5 Generators:
# (_dystack pid=93579) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=93579) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=93579) 		('float', []) : 140 | ['selfclarity_1', 'selfclarity_2', 'selfclarity_3', 'selfclarity_4', 'selfclarity_5', ...]
# (_dystack pid=93579) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=93579) 		('float', [])     : 127 | ['selfclarity_1', 'selfclarity_2', 'selfclarity_3', 'selfclarity_4', 'selfclarity_5', ...]
# (_dystack pid=93579) 		('int', ['bool']) :  13 | ['NPI1', 'NPI2', 'NPI3', 'NPI4', 'NPI5', ...]
# (_dystack pid=93579) 	0.4s = Fit runtime
# (_dystack pid=93579) 	140 features in original data used to generate 140 features in processed data.
# (_dystack pid=93579) 	Train Data (Processed) Memory Usage: 0.35 MB (0.0% of available memory)
# (_dystack pid=93579) Data preprocessing and feature engineering runtime = 0.43s ...
# (_dystack pid=93579) AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# (_dystack pid=93579) 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# (_dystack pid=93579) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=93579) Large model count detected (110 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# (_dystack pid=93579) User-specified model hyperparameters to be fit:
# (_dystack pid=93579) {
# (_dystack pid=93579) 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# (_dystack pid=93579) 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# (_dystack pid=93579) 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# (_dystack pid=93579) 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# (_dystack pid=93579) 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# (_dystack pid=93579) 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=93579) 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=93579) }
# (_dystack pid=93579) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=93579) Fitting 106 L1 models, fit_strategy="sequential" ...
# (_dystack pid=93579) Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 594.33s of the 891.69s of remaining time.
# (_dystack pid=93579) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.83%)
# (_dystack pid=93579) 	-1.0232	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=93579) 	9.82s	 = Training   runtime
# (_dystack pid=93579) 	0.01s	 = Validation runtime
# (_dystack pid=93579) Fitting model: LightGBM_BAG_L1 ... Training model for up to 563.65s of the 861.02s of remaining time.
# (_dystack pid=93579) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.12%)
# (_dystack pid=93579) 	-1.0158	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=93579) 	7.28s	 = Training   runtime
# (_dystack pid=93579) 	0.02s	 = Validation runtime
# (_dystack pid=93579) Fitting model: RandomForestMSE_BAG_L1 ... Training model for up to 545.47s of the 842.84s of remaining time.
# (_dystack pid=93579) 	-1.059	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=93579) 	2.26s	 = Training   runtime
# (_dystack pid=93579) 	0.17s	 = Validation runtime
# (_dystack pid=93579) Fitting model: CatBoost_BAG_L1 ... Training model for up to 542.98s of the 840.34s of remaining time.
# (_dystack pid=93579) 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 15.42% memory usage per fold, 61.69%/80.00% total).
# (_dystack pid=93579) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=2, gpus=0, memory=15.42%)
# (_dystack pid=93579) 	-1.0089	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=93579) 	21.58s	 = Training   runtime
# (_dystack pid=93579) 	0.08s	 = Validation runtime
# (_dystack pid=93579) Fitting model: ExtraTreesMSE_BAG_L1 ... Training model for up to 512.63s of the 810.00s of remaining time.
# (_dystack pid=93579) 	-1.0486	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=93579) 	0.9s	 = Training   runtime
# (_dystack pid=93579) 	0.25s	 = Validation runtime
# (_dystack pid=93579) Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 511.43s of the 808.79s of remaining time.
# (_dystack pid=93579) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.13%)
# (_ray_fit pid=93888) No improvement since epoch 5: early stopping
# (_dystack pid=93579) 	-1.0136	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=93579) 	11.58s	 = Training   runtime
# (_dystack pid=93579) 	0.15s	 = Validation runtime
# (_dystack pid=93579) Fitting model: XGBoost_BAG_L1 ... Training model for up to 489.40s of the 786.77s of remaining time.
# (_dystack pid=93579) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.82%)
# (_dystack pid=93579) 	-1.0167	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=93579) 	1.58s	 = Training   runtime
# (_dystack pid=93579) 	0.02s	 = Validation runtime
# (_dystack pid=93579) Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 479.87s of the 777.24s of remaining time.
# (_ray_fit pid=93890) No improvement since epoch 5: early stopping [repeated 5x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (_dystack pid=93579) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.06%)
# (_dystack pid=93579) 	-1.0192	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=93579) 	17.01s	 = Training   runtime
# (_dystack pid=93579) 	0.47s	 = Validation runtime
# (_dystack pid=93579) Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 451.49s of the 748.86s of remaining time.
# (_dystack pid=93579) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=3.98%)
# (_dystack pid=93579) 	-1.0259	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=93579) 	6.49s	 = Training   runtime
# (_dystack pid=93579) 	0.04s	 = Validation runtime
# (_dystack pid=93579) Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 430.91s of the 728.28s of remaining time.
# (_dystack pid=93579) 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 13.57% memory usage per fold, 54.26%/80.00% total).
# (_dystack pid=93579) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=2, gpus=0, memory=13.57%)
# (_dystack pid=93579) 	-1.0105	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=93579) 	15.44s	 = Training   runtime
# (_dystack pid=93579) 	0.04s	 = Validation runtime
# (_dystack pid=93579) Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 408.32s of the 705.69s of remaining time.
# (_dystack pid=93579) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.05%)
# (_dystack pid=93579) 	-1.067	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=93579) 	42.18s	 = Training   runtime
# (_dystack pid=93579) 	0.54s	 = Validation runtime
# (_dystack pid=93579) Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 352.69s of the 650.05s of remaining time.
# (_dystack pid=93579) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.37%)
# (_dystack pid=93579) 	-1.0166	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=93579) 	8.83s	 = Training   runtime
# (_dystack pid=93579) 	0.01s	 = Validation runtime
# (_dystack pid=93579) Fitting model: NeuralNetFastAI_r191_BAG_L1 ... Training model for up to 326.00s of the 623.37s of remaining time.
# (_dystack pid=93579) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.08%)
# (_ray_fit pid=94489) No improvement since epoch 4: early stopping
# (_dystack pid=93579) 	-1.0073	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=93579) 	27.39s	 = Training   runtime
# (_dystack pid=93579) 	0.48s	 = Validation runtime
# (_dystack pid=93579) Fitting model: CatBoost_r9_BAG_L1 ... Training model for up to 285.95s of the 583.32s of remaining time.
# (_dystack pid=93579) 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 15.83% memory usage per fold, 63.31%/80.00% total).
# (_dystack pid=93579) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=2, gpus=0, memory=15.83%)
# (_dystack pid=93579) 	-1.0135	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=93579) 	147.19s	 = Training   runtime
# (_dystack pid=93579) 	0.05s	 = Validation runtime
# (_dystack pid=93579) Fitting model: LightGBM_r96_BAG_L1 ... Training model for up to 127.96s of the 425.32s of remaining time.
# (_dystack pid=93579) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.42%)
# (_ray_fit pid=94487) No improvement since epoch 10: early stopping [repeated 7x across cluster]
# (_dystack pid=93579) 	-1.0237	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=93579) 	12.62s	 = Training   runtime
# (_dystack pid=93579) 	0.03s	 = Validation runtime
# (_dystack pid=93579) Fitting model: NeuralNetTorch_r22_BAG_L1 ... Training model for up to 100.97s of the 398.33s of remaining time.
# (_dystack pid=93579) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.08%)
# (_dystack pid=93579) 	-1.0509	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=93579) 	17.32s	 = Training   runtime
# (_dystack pid=93579) 	0.54s	 = Validation runtime
# (_dystack pid=93579) Fitting model: XGBoost_r33_BAG_L1 ... Training model for up to 72.11s of the 369.48s of remaining time.
# (_dystack pid=93579) 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 11.66% memory usage per fold, 46.66%/80.00% total).
# (_dystack pid=93579) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=2, gpus=0, memory=11.66%)
# (_dystack pid=93579) 	-1.0236	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=93579) 	73.1s	 = Training   runtime
# (_dystack pid=93579) 	0.2s	 = Validation runtime
# (_dystack pid=93579) Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.00s of the 285.93s of remaining time.
# (_dystack pid=93579) 	Ensemble Weights: {'NeuralNetFastAI_r191_BAG_L1': 0.458, 'LightGBM_BAG_L1': 0.25, 'NeuralNetTorch_BAG_L1': 0.208, 'XGBoost_BAG_L1': 0.083}
# (_dystack pid=93579) 	-0.9932	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=93579) 	0.01s	 = Training   runtime
# (_dystack pid=93579) 	0.0s	 = Validation runtime
# (_dystack pid=93579) Fitting 106 L2 models, fit_strategy="sequential" ...
# (_dystack pid=93579) Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 285.90s of the 285.63s of remaining time.
# (_dystack pid=93579) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.81%)
# (_ray_fit pid=95586) [1000]	valid_set's rmse: 0.933595
# (_dystack pid=93579) 	-1.0096	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=93579) 	30.5s	 = Training   runtime
# (_dystack pid=93579) 	0.47s	 = Validation runtime
# (_dystack pid=93579) Fitting model: LightGBM_BAG_L2 ... Training model for up to 238.34s of the 238.07s of remaining time.
# (_dystack pid=93579) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.07%)
# (_ray_fit pid=95743) [1000]	valid_set's rmse: 0.999741
# (_ray_fit pid=95743) [2000]	valid_set's rmse: 0.998019
# (_ray_fit pid=95743) [3000]	valid_set's rmse: 0.997855
# (_ray_fit pid=95743) [4000]	valid_set's rmse: 0.997798
# (_ray_fit pid=95743) [5000]	valid_set's rmse: 0.997785
# (_ray_fit pid=95743) [6000]	valid_set's rmse: 0.997782
# (_ray_fit pid=95743) [7000]	valid_set's rmse: 0.997782
# (_ray_fit pid=95743) [8000]	valid_set's rmse: 0.997782
# (_ray_fit pid=95743) [9000]	valid_set's rmse: 0.997782
# (_ray_fit pid=95743) [10000]	valid_set's rmse: 0.997782
# (_dystack pid=93579) 	-1.0079	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=93579) 	82.13s	 = Training   runtime
# (_dystack pid=93579) 	0.76s	 = Validation runtime
# (_dystack pid=93579) Fitting model: RandomForestMSE_BAG_L2 ... Training model for up to 108.82s of the 108.56s of remaining time.
# (_dystack pid=93579) 	-1.0245	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=93579) 	5.61s	 = Training   runtime
# (_dystack pid=93579) 	1.3s	 = Validation runtime
# (_dystack pid=93579) Fitting model: CatBoost_BAG_L2 ... Training model for up to 101.82s of the 101.55s of remaining time.
# (_dystack pid=93579) 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 16.59% memory usage per fold, 66.36%/80.00% total).
# (_dystack pid=93579) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=2, gpus=0, memory=16.59%)
# (_ray_fit pid=96172) 	Ran out of time, early stopping on iteration 1431.
# (_dystack pid=93579) 	-1.0063	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=93579) 	71.89s	 = Training   runtime
# (_dystack pid=93579) 	3.92s	 = Validation runtime
# (_dystack pid=93579) Fitting model: ExtraTreesMSE_BAG_L2 ... Training model for up to 12.58s of the 12.32s of remaining time.
# (_dystack pid=93579) 	-1.0268	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=93579) 	0.85s	 = Training   runtime
# (_dystack pid=93579) 	0.27s	 = Validation runtime
# (_dystack pid=93579) Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 11.40s of the 11.13s of remaining time.
# (_dystack pid=93579) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.10%)
# (_ray_fit pid=96445) No improvement since epoch 3: early stopping
# (_ray_fit pid=96451) No improvement since epoch 6: early stopping
# (_ray_fit pid=96448) No improvement since epoch 8: early stopping
# (_dystack pid=93579) 	-0.9935	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=93579) 	24.52s	 = Training   runtime
# (_dystack pid=93579) 	0.31s	 = Validation runtime
# (_dystack pid=93579) Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.00s of the -24.91s of remaining time.
# (_dystack pid=93579) 	Ensemble Weights: {'NeuralNetFastAI_BAG_L2': 0.524, 'LightGBM_BAG_L2': 0.286, 'CatBoost_BAG_L2': 0.19}
# (_dystack pid=93579) 	-0.979	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=93579) 	0.01s	 = Training   runtime
# (_dystack pid=93579) 	0.0s	 = Validation runtime
# (_dystack pid=93579) AutoGluon training complete, total runtime = 917.09s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 7.4 rows/s (45 batch size)
# (_dystack pid=93579) TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/Users/sunxinru/Desktop/ML/Code/agModels-predictSWB/ds_sub_fit/sub_fit_ho")
# (_dystack pid=93579) Deleting DyStack predictor artifacts (clean_up_fits=True) ...
# Leaderboard on holdout data (DyStack):
#                           model  score_holdout  score_val              eval_metric  pred_time_test  pred_time_val    fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0        NeuralNetFastAI_BAG_L2      -0.803848  -0.993509  root_mean_squared_error        4.373986       1.801064  102.523543                 0.426973                0.305301          24.519786            2       True         24
# 1           WeightedEnsemble_L3      -0.817170  -0.978963  root_mean_squared_error        4.873676       6.476533  256.555925                 0.002411                0.000265           0.011521            3       True         25
# 2        NeuralNetFastAI_BAG_L1      -0.825400  -1.013605  root_mean_squared_error        3.343606       0.150971   11.583662                 3.343606                0.150971          11.583662            1       True          6
# 3   NeuralNetFastAI_r191_BAG_L1      -0.828186  -1.007322  root_mean_squared_error        0.652039       0.481075   27.389880                 0.652039                0.481075          27.389880            1       True         13
# 4        RandomForestMSE_BAG_L2      -0.830183  -1.024454  root_mean_squared_error        3.995933       2.797738   83.609284                 0.048920                1.301975           5.605527            2       True         21
# 5           WeightedEnsemble_L2      -0.833675  -0.993152  root_mean_squared_error        2.024232       0.997801   53.279098                 0.002173                0.000351           0.012160            2       True         18
# 6        RandomForestMSE_BAG_L1      -0.836874  -1.058988  root_mean_squared_error        0.046669       0.168038    2.262151                 0.046669                0.168038           2.262151            1       True          3
# 7          ExtraTreesMSE_BAG_L1      -0.841013  -1.048629  root_mean_squared_error        0.070333       0.249672    0.897982                 0.070333                0.249672           0.897982            1       True          5
# 8               CatBoost_BAG_L2      -0.842211  -1.006306  root_mean_squared_error        3.988756       5.412559  149.895439                 0.041744                3.916795          71.891682            2       True         22
# 9                XGBoost_BAG_L1      -0.842334  -1.016741  root_mean_squared_error        0.598237       0.024963    1.582128                 0.598237                0.024963           1.582128            1       True          7
# 10    NeuralNetTorch_r22_BAG_L1      -0.843483  -1.050948  root_mean_squared_error        0.349376       0.535251   17.322569                 0.349376                0.535251          17.322569            1       True         16
# 11              LightGBM_BAG_L1      -0.844089  -1.015797  root_mean_squared_error        0.339731       0.023965    7.281515                 0.339731                0.023965           7.281515            1       True          2
# 12           CatBoost_r9_BAG_L1      -0.845753  -1.013540  root_mean_squared_error        0.043898       0.051418  147.190977                 0.043898                0.051418         147.190977            1       True         14
# 13         LightGBM_r131_BAG_L1      -0.846873  -1.016636  root_mean_squared_error        0.490773       0.013945    8.833120                 0.490773                0.013945           8.833120            1       True         12
# 14              LightGBM_BAG_L2      -0.850042  -1.007912  root_mean_squared_error        4.402547       2.254172  160.132936                 0.455535                0.758409          82.129179            2       True         20
# 15        NeuralNetTorch_BAG_L1      -0.852391  -1.019198  root_mean_squared_error        0.432052       0.467446   17.013415                 0.432052                0.467446          17.013415            1       True          8
# 16              CatBoost_BAG_L1      -0.852774  -1.008946  root_mean_squared_error        1.807952       0.080603   21.576686                 1.807952                0.080603          21.576686            1       True          4
# 17           XGBoost_r33_BAG_L1      -0.854863  -1.023597  root_mean_squared_error        0.539501       0.203475   73.097543                 0.539501                0.203475          73.097543            1       True         17
# 18         ExtraTreesMSE_BAG_L2      -0.856067  -1.026789  root_mean_squared_error        3.994144       1.769608   78.853765                 0.047132                0.273845           0.850008            2       True         23
# 19         CatBoost_r177_BAG_L1      -0.856809  -1.010508  root_mean_squared_error        0.027127       0.041794   15.440638                 0.027127                0.041794          15.440638            1       True         10
# 20    NeuralNetTorch_r79_BAG_L1      -0.857553  -1.066979  root_mean_squared_error        0.890606       0.544139   42.175601                 0.890606                0.544139          42.175601            1       True         11
# 21            LightGBMXT_BAG_L1      -0.860638  -1.023201  root_mean_squared_error        9.131875       0.013907    9.818099                 9.131875                0.013907           9.818099            1       True          1
# 22            LightGBMXT_BAG_L2      -0.863153  -1.009589  root_mean_squared_error        4.337058       1.965230  108.502610                 0.390046                0.469466          30.498853            2       True         19
# 23          LightGBM_r96_BAG_L1      -0.868617  -1.023675  root_mean_squared_error        0.363037       0.029601   12.619484                 0.363037                0.029601          12.619484            1       True         15
# 24         LightGBMLarge_BAG_L1      -0.869020  -1.025903  root_mean_squared_error        0.367406       0.039272    6.485079                 0.367406                0.039272           6.485079            1       True          9
# 	1	 = Optimal   num_stack_levels (Stacked Overfitting Occurred: False)
# 	955s	 = DyStack   runtime |	2645s	 = Remaining runtime
# Starting main fit with num_stack_levels=1.
# 	For future fit calls on this dataset, you can skip DyStack to save time: `predictor.fit(..., dynamic_stacking=False, num_stack_levels=1)`
# Beginning AutoGluon training ... Time limit = 2645s
# AutoGluon will save models to "/Users/sunxinru/Desktop/ML/Code/agModels-predictSWB"
# Train Data Rows:    402
# Train Data Columns: 140
# Label Column:       SWB
# Problem Type:       regression
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    3914.15 MB
# 	Train Data (Original)  Memory Usage: 0.43 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 13 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 140 | ['selfclarity_1', 'selfclarity_2', 'selfclarity_3', 'selfclarity_4', 'selfclarity_5', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 127 | ['selfclarity_1', 'selfclarity_2', 'selfclarity_3', 'selfclarity_4', 'selfclarity_5', ...]
# 		('int', ['bool']) :  13 | ['NPI1', 'NPI2', 'NPI3', 'NPI4', 'NPI5', ...]
# 	0.5s = Fit runtime
# 	140 features in original data used to generate 140 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.39 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.55s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (110 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 106 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 1762.24s of the 2644.00s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.78%)
# 	-1.0099	 = Validation score   (-root_mean_squared_error)
# 	8.75s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 1730.33s of the 2612.09s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.10%)
# 	-1.0048	 = Validation score   (-root_mean_squared_error)
# 	24.46s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ... Training model for up to 1689.32s of the 2571.09s of remaining time.
# 	-1.0237	 = Validation score   (-root_mean_squared_error)
# 	7.26s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 1681.77s of the 2563.54s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 16.37% memory usage per fold, 65.49%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=2, gpus=0, memory=16.37%)
# 	-0.9982	 = Validation score   (-root_mean_squared_error)
# 	41.27s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ... Training model for up to 1605.93s of the 2487.70s of remaining time.
# 	-1.0175	 = Validation score   (-root_mean_squared_error)
# 	3.64s	 = Training   runtime
# 	1.13s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 1601.10s of the 2482.87s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.11%)
# 	-0.987	 = Validation score   (-root_mean_squared_error)
# 	34.42s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 1539.68s of the 2421.45s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.76%)
# 	-1.0016	 = Validation score   (-root_mean_squared_error)
# 	4.47s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 1515.92s of the 2397.69s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.06%)
# 	-1.0054	 = Validation score   (-root_mean_squared_error)
# 	33.91s	 = Training   runtime
# 	1.52s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 1466.32s of the 2348.08s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=3.60%)
# 	-1.0073	 = Validation score   (-root_mean_squared_error)
# 	19.19s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 1430.38s of the 2312.14s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 18.35% memory usage per fold, 73.41%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=2, gpus=0, memory=18.35%)
# 	-1.0004	 = Validation score   (-root_mean_squared_error)
# 	31.47s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: NeuralNetTorch_r79_BAG_L1 ... Training model for up to 1381.83s of the 2263.60s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.05%)
# 	-1.0333	 = Validation score   (-root_mean_squared_error)
# 	77.23s	 = Training   runtime
# 	1.37s	 = Validation runtime
# Fitting model: LightGBM_r131_BAG_L1 ... Training model for up to 1284.72s of the 2166.48s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.64%)
# 	-1.0061	 = Validation score   (-root_mean_squared_error)
# 	13.35s	 = Training   runtime
# 	0.03s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r191_BAG_L1 ... Training model for up to 1249.67s of the 2131.43s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.11%)
# 	-0.986	 = Validation score   (-root_mean_squared_error)
# 	20.06s	 = Training   runtime
# 	0.4s	 = Validation runtime
# Fitting model: CatBoost_r9_BAG_L1 ... Training model for up to 1217.02s of the 2098.79s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 15.47% memory usage per fold, 61.89%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=2, gpus=0, memory=15.47%)
# 	-1.0038	 = Validation score   (-root_mean_squared_error)
# 	188.94s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: LightGBM_r96_BAG_L1 ... Training model for up to 1014.03s of the 1895.80s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.39%)
# 	-1.0113	 = Validation score   (-root_mean_squared_error)
# 	6.27s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetTorch_r22_BAG_L1 ... Training model for up to 996.03s of the 1877.80s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.06%)
# 	-1.0424	 = Validation score   (-root_mean_squared_error)
# 	17.78s	 = Training   runtime
# 	0.49s	 = Validation runtime
# Fitting model: XGBoost_r33_BAG_L1 ... Training model for up to 965.56s of the 1847.32s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 12.34% memory usage per fold, 49.34%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=2, gpus=0, memory=12.34%)
# 	-1.0036	 = Validation score   (-root_mean_squared_error)
# 	411.4s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: ExtraTrees_r42_BAG_L1 ... Training model for up to 541.25s of the 1423.01s of remaining time.
# 	-1.0231	 = Validation score   (-root_mean_squared_error)
# 	0.59s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: CatBoost_r137_BAG_L1 ... Training model for up to 540.51s of the 1422.27s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 11.28% memory usage per fold, 45.11%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=2, gpus=0, memory=11.28%)
# 	-1.0042	 = Validation score   (-root_mean_squared_error)
# 	10.52s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r102_BAG_L1 ... Training model for up to 525.44s of the 1407.21s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.13%)
# 	-1.0356	 = Validation score   (-root_mean_squared_error)
# 	21.27s	 = Training   runtime
# 	0.38s	 = Validation runtime
# Fitting model: CatBoost_r13_BAG_L1 ... Training model for up to 494.97s of the 1376.74s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 17.20% memory usage per fold, 68.80%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=2, gpus=0, memory=17.20%)
# 	-1.0083	 = Validation score   (-root_mean_squared_error)
# 	51.7s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: RandomForest_r195_BAG_L1 ... Training model for up to 431.51s of the 1313.28s of remaining time.
# 	-1.0203	 = Validation score   (-root_mean_squared_error)
# 	2.93s	 = Training   runtime
# 	0.23s	 = Validation runtime
# Fitting model: LightGBM_r188_BAG_L1 ... Training model for up to 428.09s of the 1309.86s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=3.69%)
# 	-1.0132	 = Validation score   (-root_mean_squared_error)
# 	13.87s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r145_BAG_L1 ... Training model for up to 395.55s of the 1277.31s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.10%)
# 	-0.9881	 = Validation score   (-root_mean_squared_error)
# 	15.07s	 = Training   runtime
# 	0.51s	 = Validation runtime
# Fitting model: XGBoost_r89_BAG_L1 ... Training model for up to 368.69s of the 1250.46s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=1.81%)
# 	-1.004	 = Validation score   (-root_mean_squared_error)
# 	2.82s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: NeuralNetTorch_r30_BAG_L1 ... Training model for up to 351.79s of the 1233.55s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.07%)
# 	-1.0177	 = Validation score   (-root_mean_squared_error)
# 	11.26s	 = Training   runtime
# 	0.35s	 = Validation runtime
# Fitting model: LightGBM_r130_BAG_L1 ... Training model for up to 330.83s of the 1212.59s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=2.23%)
# 	-1.0057	 = Validation score   (-root_mean_squared_error)
# 	5.59s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: NeuralNetTorch_r86_BAG_L1 ... Training model for up to 314.45s of the 1196.21s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.07%)
# 	-1.0203	 = Validation score   (-root_mean_squared_error)
# 	21.36s	 = Training   runtime
# 	1.03s	 = Validation runtime
# Fitting model: CatBoost_r50_BAG_L1 ... Training model for up to 282.55s of the 1164.31s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 15.11% memory usage per fold, 60.46%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=2, gpus=0, memory=15.11%)
# 	-0.9917	 = Validation score   (-root_mean_squared_error)
# 	27.62s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r11_BAG_L1 ... Training model for up to 238.86s of the 1120.62s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.13%)
# 	-1.0421	 = Validation score   (-root_mean_squared_error)
# 	19.59s	 = Training   runtime
# 	0.51s	 = Validation runtime
# Fitting model: XGBoost_r194_BAG_L1 ... Training model for up to 207.07s of the 1088.83s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=3.91%)
# 	-0.9998	 = Validation score   (-root_mean_squared_error)
# 	3.2s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Fitting model: ExtraTrees_r172_BAG_L1 ... Training model for up to 187.07s of the 1068.83s of remaining time.
# 	-1.0244	 = Validation score   (-root_mean_squared_error)
# 	0.72s	 = Training   runtime
# 	0.39s	 = Validation runtime
# Fitting model: CatBoost_r69_BAG_L1 ... Training model for up to 185.90s of the 1067.67s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 12.70% memory usage per fold, 50.80%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=2, gpus=0, memory=12.70%)
# 	-0.9997	 = Validation score   (-root_mean_squared_error)
# 	18.77s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r103_BAG_L1 ... Training model for up to 159.19s of the 1040.96s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.13%)
# 	-1.0124	 = Validation score   (-root_mean_squared_error)
# 	16.49s	 = Training   runtime
# 	0.56s	 = Validation runtime
# Fitting model: NeuralNetTorch_r14_BAG_L1 ... Training model for up to 128.23s of the 1010.00s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.09%)
# 	-1.0207	 = Validation score   (-root_mean_squared_error)
# 	28.79s	 = Training   runtime
# 	0.43s	 = Validation runtime
# Fitting model: LightGBM_r161_BAG_L1 ... Training model for up to 79.10s of the 960.86s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=5.87%)
# 	-1.0026	 = Validation score   (-root_mean_squared_error)
# 	8.23s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: NeuralNetFastAI_r143_BAG_L1 ... Training model for up to 57.80s of the 939.56s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.10%)
# 	-0.9815	 = Validation score   (-root_mean_squared_error)
# 	35.09s	 = Training   runtime
# 	1.1s	 = Validation runtime
# Fitting model: CatBoost_r70_BAG_L1 ... Training model for up to 9.94s of the 891.70s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 18.37% memory usage per fold, 73.50%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=2, gpus=0, memory=18.37%)
# 	-1.0027	 = Validation score   (-root_mean_squared_error)
# 	18.87s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.00s of the 845.57s of remaining time.
# 	Ensemble Weights: {'NeuralNetFastAI_r143_BAG_L1': 0.652, 'CatBoost_r50_BAG_L1': 0.261, 'XGBoost_r194_BAG_L1': 0.087}
# 	-0.9783	 = Validation score   (-root_mean_squared_error)
# 	0.02s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 106 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 845.53s of the 845.25s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (8 workers, per: cpus=1, gpus=0, memory=0.73%)
# 	-0.9913	 = Validation score   (-root_mean_squared_error)
# 	4.77s	 = Training   runtime
# ...
#    'save_bag_folds': True,
#    'stratify': 'auto',
#    'bin': 'auto',
#    'n_bins': None},
#   'LightGBM_BAG_L2': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'stratify': 'auto',
#    'bin': 'auto',
#    'n_bins': None},
#   'RandomForestMSE_BAG_L2': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'stratify': 'auto',
#    'bin': 'auto',
#    'n_bins': None,
#    'use_child_oof': True},
#   'CatBoost_BAG_L2': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'stratify': 'auto',
#    'bin': 'auto',
#    'n_bins': None},
#   'ExtraTreesMSE_BAG_L2': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'stratify': 'auto',
#    'bin': 'auto',
#    'n_bins': None,
#    'use_child_oof': True},
#   'NeuralNetFastAI_BAG_L2': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'stratify': 'auto',
#    'bin': 'auto',
#    'n_bins': None},
#   'XGBoost_BAG_L2': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'stratify': 'auto',
#    'bin': 'auto',
#    'n_bins': None},
#   'NeuralNetTorch_BAG_L2': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'stratify': 'auto',
#    'bin': 'auto',
#    'n_bins': None},
#   'LightGBMLarge_BAG_L2': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'stratify': 'auto',
#    'bin': 'auto',
#    'n_bins': None},
#   'CatBoost_r177_BAG_L2': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'stratify': 'auto',
#    'bin': 'auto',
#    'n_bins': None},
#   'NeuralNetTorch_r79_BAG_L2': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'stratify': 'auto',
#    'bin': 'auto',
#    'n_bins': None},
#   'LightGBM_r131_BAG_L2': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'stratify': 'auto',
#    'bin': 'auto',
#    'n_bins': None},
#   'NeuralNetFastAI_r191_BAG_L2': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'stratify': 'auto',
#    'bin': 'auto',
#    'n_bins': None},
#   'CatBoost_r9_BAG_L2': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'stratify': 'auto',
#    'bin': 'auto',
#    'n_bins': None},
#   'LightGBM_r96_BAG_L2': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'stratify': 'auto',
#    'bin': 'auto',
#    'n_bins': None},
#   'NeuralNetTorch_r22_BAG_L2': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'stratify': 'auto',
#    'bin': 'auto',
#    'n_bins': None},
#   'XGBoost_r33_BAG_L2': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'stratify': 'auto',
#    'bin': 'auto',
#    'n_bins': None},
#   'ExtraTrees_r42_BAG_L2': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'stratify': 'auto',
#    'bin': 'auto',
#    'n_bins': None,
#    'use_child_oof': True},
#   'CatBoost_r137_BAG_L2': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'stratify': 'auto',
#    'bin': 'auto',
#    'n_bins': None},
#   'WeightedEnsemble_L3': {'use_orig_features': False,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'stratify': 'auto',
#    'bin': 'auto',
#    'n_bins': None}},
#  'leaderboard':                           model  score_val              eval_metric  \
#  0           WeightedEnsemble_L3  -0.952136  root_mean_squared_error
#  1               LightGBM_BAG_L2  -0.957077  root_mean_squared_error
#  2               CatBoost_BAG_L2  -0.964133  root_mean_squared_error
#  3                XGBoost_BAG_L2  -0.965942  root_mean_squared_error
#  4          CatBoost_r137_BAG_L2  -0.967914  root_mean_squared_error
#  5            XGBoost_r33_BAG_L2  -0.968821  root_mean_squared_error
#  6          LightGBM_r131_BAG_L2  -0.972389  root_mean_squared_error
#  7          CatBoost_r177_BAG_L2  -0.972565  root_mean_squared_error
#  8           WeightedEnsemble_L2  -0.978285  root_mean_squared_error
#  9   NeuralNetFastAI_r143_BAG_L1  -0.981468  root_mean_squared_error
#  10           CatBoost_r9_BAG_L2  -0.982029  root_mean_squared_error
#  11       NeuralNetFastAI_BAG_L2  -0.983647  root_mean_squared_error
#  12  NeuralNetFastAI_r191_BAG_L1  -0.986046  root_mean_squared_error
#  13       NeuralNetFastAI_BAG_L1  -0.986972  root_mean_squared_error
#  14  NeuralNetFastAI_r145_BAG_L1  -0.988104  root_mean_squared_error
#  15          LightGBM_r96_BAG_L2  -0.988319  root_mean_squared_error
#  16  NeuralNetFastAI_r191_BAG_L2  -0.989699  root_mean_squared_error
#  17         LightGBMLarge_BAG_L2  -0.990120  root_mean_squared_error
#  18       RandomForestMSE_BAG_L2  -0.990923  root_mean_squared_error
#  19            LightGBMXT_BAG_L2  -0.991336  root_mean_squared_error
#  20          CatBoost_r50_BAG_L1  -0.991727  root_mean_squared_error
#  21              CatBoost_BAG_L1  -0.998233  root_mean_squared_error
#  22        NeuralNetTorch_BAG_L2  -0.999214  root_mean_squared_error
#  23          CatBoost_r69_BAG_L1  -0.999679  root_mean_squared_error
#  24          XGBoost_r194_BAG_L1  -0.999799  root_mean_squared_error
#  25         CatBoost_r177_BAG_L1  -1.000424  root_mean_squared_error
#  26               XGBoost_BAG_L1  -1.001552  root_mean_squared_error
#  27         ExtraTreesMSE_BAG_L2  -1.002406  root_mean_squared_error
#  28         LightGBM_r161_BAG_L1  -1.002593  root_mean_squared_error
#  29          CatBoost_r70_BAG_L1  -1.002741  root_mean_squared_error
#  30           XGBoost_r33_BAG_L1  -1.003617  root_mean_squared_error
#  31           CatBoost_r9_BAG_L1  -1.003844  root_mean_squared_error
#  32           XGBoost_r89_BAG_L1  -1.004043  root_mean_squared_error
#  33         CatBoost_r137_BAG_L1  -1.004232  root_mean_squared_error
#  34              LightGBM_BAG_L1  -1.004840  root_mean_squared_error
#  35        NeuralNetTorch_BAG_L1  -1.005357  root_mean_squared_error
#  36         LightGBM_r130_BAG_L1  -1.005727  root_mean_squared_error
#  37         LightGBM_r131_BAG_L1  -1.006111  root_mean_squared_error
#  38         LightGBMLarge_BAG_L1  -1.007338  root_mean_squared_error
#  39          CatBoost_r13_BAG_L1  -1.008292  root_mean_squared_error
#  40        ExtraTrees_r42_BAG_L2  -1.008921  root_mean_squared_error
#  41            LightGBMXT_BAG_L1  -1.009928  root_mean_squared_error
#  42          LightGBM_r96_BAG_L1  -1.011270  root_mean_squared_error
#  43  NeuralNetFastAI_r103_BAG_L1  -1.012384  root_mean_squared_error
#  44         LightGBM_r188_BAG_L1  -1.013202  root_mean_squared_error
#  45         ExtraTreesMSE_BAG_L1  -1.017467  root_mean_squared_error
#  46    NeuralNetTorch_r30_BAG_L1  -1.017689  root_mean_squared_error
#  47     RandomForest_r195_BAG_L1  -1.020337  root_mean_squared_error
#  48    NeuralNetTorch_r86_BAG_L1  -1.020343  root_mean_squared_error
#  49    NeuralNetTorch_r14_BAG_L1  -1.020699  root_mean_squared_error
#  50        ExtraTrees_r42_BAG_L1  -1.023108  root_mean_squared_error
#  51       RandomForestMSE_BAG_L1  -1.023684  root_mean_squared_error
#  52       ExtraTrees_r172_BAG_L1  -1.024375  root_mean_squared_error
#  53    NeuralNetTorch_r79_BAG_L2  -1.031304  root_mean_squared_error
#  54    NeuralNetTorch_r79_BAG_L1  -1.033287  root_mean_squared_error
#  55  NeuralNetFastAI_r102_BAG_L1  -1.035550  root_mean_squared_error
#  56    NeuralNetTorch_r22_BAG_L2  -1.036056  root_mean_squared_error
#  57   NeuralNetFastAI_r11_BAG_L1  -1.042070  root_mean_squared_error
#  58    NeuralNetTorch_r22_BAG_L1  -1.042385  root_mean_squared_error
#
#      pred_time_val    fit_time  pred_time_val_marginal  fit_time_marginal  \
#  
#  23            1       True         33
#  24            1       True         31
#  25            1       True         10
#  26            1       True          7
#  27            2       True         44
#  28            1       True         36
#  29            1       True         38
#  30            1       True         17
#  31            1       True         14
#  32            1       True         25
#  33            1       True         19
#  34            1       True          2
#  35            1       True          8
#  36            1       True         27
#  37            1       True         12
#  38            1       True          9
#  39            1       True         21
#  40            2       True         57
#  41            1       True          1
#  42            1       True         15
#  43            1       True         34
#  44            1       True         23
#  45            1       True          5
#  46            1       True         26
#  47            1       True         22
#  48            1       True         28
#  49            1       True         35
#  50            1       True         18
#  51            1       True          3
#  52            1       True         32
#  53            2       True         50
#  54            1       True         11
#  55            1       True         20
#  56            2       True         55
#  57            1       True         30
#  58            1       True         16  }

# %%
# Evaluate the model on the test data
predictor.evaluate(test_data)
# Out:
# {'root_mean_squared_error': -0.9765426414701425,
#  'mean_squared_error': -0.9536355306094831,
#  'mean_absolute_error': -0.8453142042296621,
#  'r2': -0.07613643808720139,
#  'pearsonr': -0.1291676616686998,
#  'median_absolute_error': -0.8079074828297468}

# %%
# Display the best model
predictor.model_best
# Out:
# 'WeightedEnsemble_L3'

# %%
# 查看所有模型及其性能指标
leaderboard = predictor.leaderboard(silent=True)
print(leaderboard)

# 查看 WeightedEnsemble_L3 的详细信息（包括子模型和权重）
info = predictor.info()
print(info['model_info']['WeightedEnsemble_L3'])
# Out:
#                           model  score_val              eval_metric  \
# 0           WeightedEnsemble_L3  -0.952136  root_mean_squared_error
# 1               LightGBM_BAG_L2  -0.957077  root_mean_squared_error
# 2               CatBoost_BAG_L2  -0.964133  root_mean_squared_error
# 3                XGBoost_BAG_L2  -0.965942  root_mean_squared_error
# 4          CatBoost_r137_BAG_L2  -0.967914  root_mean_squared_error
# 5            XGBoost_r33_BAG_L2  -0.968821  root_mean_squared_error
# 6          LightGBM_r131_BAG_L2  -0.972389  root_mean_squared_error
# 7          CatBoost_r177_BAG_L2  -0.972565  root_mean_squared_error
# 8           WeightedEnsemble_L2  -0.978285  root_mean_squared_error
# 9   NeuralNetFastAI_r143_BAG_L1  -0.981468  root_mean_squared_error
# 10           CatBoost_r9_BAG_L2  -0.982029  root_mean_squared_error
# 11       NeuralNetFastAI_BAG_L2  -0.983647  root_mean_squared_error
# 12  NeuralNetFastAI_r191_BAG_L1  -0.986046  root_mean_squared_error
# 13       NeuralNetFastAI_BAG_L1  -0.986972  root_mean_squared_error
# 14  NeuralNetFastAI_r145_BAG_L1  -0.988104  root_mean_squared_error
# 15          LightGBM_r96_BAG_L2  -0.988319  root_mean_squared_error
# 16  NeuralNetFastAI_r191_BAG_L2  -0.989699  root_mean_squared_error
# 17         LightGBMLarge_BAG_L2  -0.990120  root_mean_squared_error
# 18       RandomForestMSE_BAG_L2  -0.990923  root_mean_squared_error
# 19            LightGBMXT_BAG_L2  -0.991336  root_mean_squared_error
# 20          CatBoost_r50_BAG_L1  -0.991727  root_mean_squared_error
# 21              CatBoost_BAG_L1  -0.998233  root_mean_squared_error
# 22        NeuralNetTorch_BAG_L2  -0.999214  root_mean_squared_error
# 23          CatBoost_r69_BAG_L1  -0.999679  root_mean_squared_error
# 24          XGBoost_r194_BAG_L1  -0.999799  root_mean_squared_error
# 25         CatBoost_r177_BAG_L1  -1.000424  root_mean_squared_error
# 26               XGBoost_BAG_L1  -1.001552  root_mean_squared_error
# 27         ExtraTreesMSE_BAG_L2  -1.002406  root_mean_squared_error
# 28         LightGBM_r161_BAG_L1  -1.002593  root_mean_squared_error
# 29          CatBoost_r70_BAG_L1  -1.002741  root_mean_squared_error
# 30           XGBoost_r33_BAG_L1  -1.003617  root_mean_squared_error
# 31           CatBoost_r9_BAG_L1  -1.003844  root_mean_squared_error
# 32           XGBoost_r89_BAG_L1  -1.004043  root_mean_squared_error
# 33         CatBoost_r137_BAG_L1  -1.004232  root_mean_squared_error
# 34              LightGBM_BAG_L1  -1.004840  root_mean_squared_error
# 35        NeuralNetTorch_BAG_L1  -1.005357  root_mean_squared_error
# 36         LightGBM_r130_BAG_L1  -1.005727  root_mean_squared_error
# 37         LightGBM_r131_BAG_L1  -1.006111  root_mean_squared_error
# 38         LightGBMLarge_BAG_L1  -1.007338  root_mean_squared_error
# 39          CatBoost_r13_BAG_L1  -1.008292  root_mean_squared_error
# 40        ExtraTrees_r42_BAG_L2  -1.008921  root_mean_squared_error
# 41            LightGBMXT_BAG_L1  -1.009928  root_mean_squared_error
# 42          LightGBM_r96_BAG_L1  -1.011270  root_mean_squared_error
# 43  NeuralNetFastAI_r103_BAG_L1  -1.012384  root_mean_squared_error
# 44         LightGBM_r188_BAG_L1  -1.013202  root_mean_squared_error
# 45         ExtraTreesMSE_BAG_L1  -1.017467  root_mean_squared_error
# 46    NeuralNetTorch_r30_BAG_L1  -1.017689  root_mean_squared_error
# 47     RandomForest_r195_BAG_L1  -1.020337  root_mean_squared_error
# 48    NeuralNetTorch_r86_BAG_L1  -1.020343  root_mean_squared_error
# 49    NeuralNetTorch_r14_BAG_L1  -1.020699  root_mean_squared_error
# 50        ExtraTrees_r42_BAG_L1  -1.023108  root_mean_squared_error
# 51       RandomForestMSE_BAG_L1  -1.023684  root_mean_squared_error
# 52       ExtraTrees_r172_BAG_L1  -1.024375  root_mean_squared_error
# 53    NeuralNetTorch_r79_BAG_L2  -1.031304  root_mean_squared_error
# 54    NeuralNetTorch_r79_BAG_L1  -1.033287  root_mean_squared_error
# 55  NeuralNetFastAI_r102_BAG_L1  -1.035550  root_mean_squared_error
# 56    NeuralNetTorch_r22_BAG_L2  -1.036056  root_mean_squared_error
# 57   NeuralNetFastAI_r11_BAG_L1  -1.042070  root_mean_squared_error
# 58    NeuralNetTorch_r22_BAG_L1  -1.042385  root_mean_squared_error
#
#     pred_time_val    fit_time  pred_time_val_marginal  fit_time_marginal  \
# 26            1       True          7
# 27            2       True         44
# 28            1       True         36
# 29            1       True         38
# 30            1       True         17
# 31            1       True         14
# 32            1       True         25
# 33            1       True         19
# 34            1       True          2
# 35            1       True          8
# 36            1       True         27
# 37            1       True         12
# 38            1       True          9
# 39            1       True         21
# 40            2       True         57
# 41            1       True          1
# 42            1       True         15
# 43            1       True         34
# 44            1       True         23
# 45            1       True          5
# 46            1       True         26
# 47            1       True         22
# 48            1       True         28
# 49            1       True         35
# 50            1       True         18
# 51            1       True          3
# 52            1       True         32
# 53            2       True         50
# 54            1       True         11
# 55            1       True         20
# 56            2       True         55
# 57            1       True         30
# 58            1       True         16
# {'name': 'WeightedEnsemble_L3', 'model_type': 'WeightedEnsembleModel', 'problem_type': 'regression', 'eval_metric': 'root_mean_squared_error', 'stopping_metric': 'root_mean_squared_error', 'fit_time': 0.010460853576660156, 'num_classes': None, 'quantile_levels': None, 'predict_time': 0.0003781318664550781, 'val_score': -0.9521363679080489, 'hyperparameters': {'use_orig_features': False, 'valid_stacker': True, 'max_base_models': 0, 'max_base_models_per_type': 'auto', 'save_bag_folds': True, 'stratify': 'auto', 'bin': 'auto', 'n_bins': None}, 'hyperparameters_user': {'save_bag_folds': True}, 'hyperparameters_fit': {}, 'hyperparameters_nondefault': ['save_bag_folds'], 'ag_args_fit': {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': None, 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None, 'drop_unique': False}, 'num_features': 4, 'features': ['LightGBM_BAG_L2', 'CatBoost_BAG_L2', 'NeuralNetTorch_BAG_L2', 'XGBoost_BAG_L2'], 'feature_metadata': <autogluon.common.features.feature_metadata.FeatureMetadata object at 0x3baecb260>, 'memory_size': 8274, 'compile_time': None, 'is_initialized': True, 'is_fit': True, 'is_valid': True, 'can_infer': True, 'has_learning_curves': False, 'num_samples': 402, 'val_in_fit': False, 'unlabeled_in_fit': False, 'num_cpus': 8, 'num_gpus': 0, 'bagged_info': {'child_model_type': 'GreedyWeightedEnsembleModel', 'num_child_models': 1, 'child_model_names': ['S1F1'], '_n_repeats': 1, '_k_per_n_repeat': [1], '_random_state': 3, 'low_memory': False, 'bagged_mode': False, 'max_memory_size': 8274, 'min_memory_size': 8274, 'child_hyperparameters': {'ensemble_size': 25, 'subsample_size': 1000000}, 'child_hyperparameters_user': {}, 'child_hyperparameters_fit': {'ensemble_size': 22}, 'child_ag_args_fit': {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': None, 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None, 'drop_unique': False}}, 'stacker_info': {'num_base_models': 4, 'base_model_names': ['LightGBM_BAG_L2', 'CatBoost_BAG_L2', 'XGBoost_BAG_L2', 'NeuralNetTorch_BAG_L2']}, 'children_info': {'S1F1': {'name': 'S1F1', 'model_type': 'GreedyWeightedEnsembleModel', 'problem_type': 'regression', 'eval_metric': 'root_mean_squared_error', 'stopping_metric': 'root_mean_squared_error', 'fit_time': 0.010460853576660156, 'num_classes': None, 'quantile_levels': None, 'predict_time': None, 'val_score': None, 'hyperparameters': {'ensemble_size': 25, 'subsample_size': 1000000}, 'hyperparameters_user': {}, 'hyperparameters_fit': {'ensemble_size': 22}, 'hyperparameters_nondefault': [], 'ag_args_fit': {'max_memory_usage_ratio': 1.0, 'max_time_limit_ratio': 1.0, 'max_time_limit': None, 'min_time_limit': 0, 'valid_raw_types': None, 'valid_special_types': None, 'ignored_type_group_special': None, 'ignored_type_group_raw': None, 'get_features_kwargs': None, 'get_features_kwargs_extra': None, 'predict_1_batch_size': None, 'temperature_scalar': None, 'drop_unique': False}, 'num_features': 4, 'features': ['LightGBM_BAG_L2', 'CatBoost_BAG_L2', 'XGBoost_BAG_L2', 'NeuralNetTorch_BAG_L2'], 'feature_metadata': <autogluon.common.features.feature_metadata.FeatureMetadata object at 0x3baecb380>, 'memory_size': 6184, 'compile_time': None, 'is_initialized': True, 'is_fit': True, 'is_valid': True, 'can_infer': True, 'has_learning_curves': False, 'num_samples': 402, 'val_in_fit': False, 'unlabeled_in_fit': False, 'num_cpus': 8, 'num_gpus': 0, 'model_weights': {'LightGBM_BAG_L2': 0.5, 'CatBoost_BAG_L2': 0.22727272727272727, 'XGBoost_BAG_L2': 0.22727272727272727, 'NeuralNetTorch_BAG ...

# %% [markdown]
# ## 1.2 Model Leaderboard
#
# View the leaderboard to see the performance of different models trained by AutoGluon.

# %%
# Display the leaderboard for models trained by AutoGluon on the test data
predictor.leaderboard(test_data)
# Out:
#                           model  score_test  score_val  \
# 0          LightGBMLarge_BAG_L1   -0.948819  -1.007338
# 1          LightGBM_r188_BAG_L1   -0.951949  -1.013202
# 2           LightGBM_r96_BAG_L1   -0.952955  -1.011270
# 3         NeuralNetTorch_BAG_L1   -0.953569  -1.005357
# 4             LightGBMXT_BAG_L1   -0.956088  -1.009928
# 5            XGBoost_r33_BAG_L1   -0.956999  -1.003617
# 6                XGBoost_BAG_L1   -0.957852  -1.001552
# 7            XGBoost_r89_BAG_L1   -0.957905  -1.004043
# 8          LightGBM_r131_BAG_L1   -0.958100  -1.006111
# 9           CatBoost_r13_BAG_L1   -0.958446  -1.008292
# 10           CatBoost_r9_BAG_L1   -0.958603  -1.003844
# 11         LightGBM_r161_BAG_L1   -0.959914  -1.002593
# 12              LightGBM_BAG_L1   -0.960260  -1.004840
# 13  NeuralNetFastAI_r143_BAG_L1   -0.961257  -0.981468
# 14          CatBoost_r70_BAG_L1   -0.961429  -1.002741
# 15         LightGBM_r130_BAG_L1   -0.961800  -1.005727
# 16         CatBoost_r137_BAG_L1   -0.961879  -1.004232
# 17          CatBoost_r69_BAG_L1   -0.962234  -0.999679
# 18          WeightedEnsemble_L2   -0.964363  -0.978285
# 19  NeuralNetFastAI_r103_BAG_L1   -0.965921  -1.012384
# 20        NeuralNetTorch_BAG_L2   -0.966339  -0.999214
# 21           CatBoost_r9_BAG_L2   -0.967786  -0.982029
# 22         LightGBM_r131_BAG_L2   -0.968448  -0.972389
# 23         LightGBMLarge_BAG_L2   -0.969668  -0.990120
# 24       NeuralNetFastAI_BAG_L1   -0.970251  -0.986972
# 25          XGBoost_r194_BAG_L1   -0.970313  -0.999799
# 26         CatBoost_r177_BAG_L1   -0.971027  -1.000424
# 27  NeuralNetFastAI_r145_BAG_L1   -0.971688  -0.988104
# 28    NeuralNetTorch_r86_BAG_L1   -0.972939  -1.020343
# 29              LightGBM_BAG_L2   -0.973173  -0.957077
# 30              CatBoost_BAG_L1   -0.973276  -0.998233
# 31       NeuralNetFastAI_BAG_L2   -0.974069  -0.983647
# 32          CatBoost_r50_BAG_L1   -0.975373  -0.991727
# 33          WeightedEnsemble_L3   -0.976543  -0.952136
# 34            LightGBMXT_BAG_L2   -0.977532  -0.991336
# 35           XGBoost_r33_BAG_L2   -0.979133  -0.968821
# 36  NeuralNetFastAI_r191_BAG_L1   -0.979898  -0.986046
# 37          LightGBM_r96_BAG_L2   -0.980352  -0.988319
# 38               XGBoost_BAG_L2   -0.982968  -0.965942
# 39         CatBoost_r177_BAG_L2   -0.984130  -0.972565
# 40    NeuralNetTorch_r30_BAG_L1   -0.984424  -1.017689
# 41         CatBoost_r137_BAG_L2   -0.986261  -0.967914
# 42              CatBoost_BAG_L2   -0.989736  -0.964133
# 43    NeuralNetTorch_r79_BAG_L1   -0.989828  -1.033287
# 44  NeuralNetFastAI_r191_BAG_L2   -0.990305  -0.989699
# 45     RandomForest_r195_BAG_L1   -0.991591  -1.020337
# 46        ExtraTrees_r42_BAG_L2   -0.992130  -1.008921
# 47    NeuralNetTorch_r22_BAG_L1   -0.992392  -1.042385
# 48       RandomForestMSE_BAG_L1   -0.996757  -1.023684
# 49    NeuralNetTorch_r79_BAG_L2   -0.997055  -1.031304
# 50        ExtraTrees_r42_BAG_L1   -0.998113  -1.023108
# 51    NeuralNetTorch_r22_BAG_L2   -0.998760  -1.036056
# 52       ExtraTrees_r172_BAG_L1   -1.001678  -1.024375
# 53         ExtraTreesMSE_BAG_L2   -1.011819  -1.002406
# 54         ExtraTreesMSE_BAG_L1   -1.013613  -1.017467
# 55       RandomForestMSE_BAG_L2   -1.022494  -0.990923
# 56  NeuralNetFastAI_r102_BAG_L1   -1.028287  -1.035550
# 57    NeuralNetTorch_r14_BAG_L1   -1.030378  -1.020699
# 58   NeuralNetFastAI_r11_BAG_L1   -1.081801  -1.042070
#
#                 eval_metric  pred_time_test  pred_time_val    fit_time  \
# 0   root_mean_squared_error        0.010092       0.071676   19.192003
# 1   root_mean_squared_error        0.015176       0.054548   13.865345
# 2   root_mean_squared_error        0.023874       0.019966    6.274511
# 3   root_mean_squared_error        0.104577       1.521532   33.906210
# 4   root_mean_squared_error        0.015225       0.019963    8.749448
# 5   root_mean_squared_error        0.070435       0.184525  411.395167
# 6   root_mean_squared_error        0.050267       0.021719    4.466851
# 7   root_mean_squared_error        0.051980       0.117294    2.823050
# 8   root_mean_squared_error        0.013377       0.026856   13.351181
# 9   root_mean_squared_error        0.038702       0.041755   51.695721
# 10  root_mean_squared_error        0.038418       0.156039  188.935800
# 11  root_mean_squared_error        0.017312       0.077648    8.226966
# 12  root_mean_squared_error        0.008683       0.115010   24.459485
# 13  root_mean_squared_error        0.087595       1.097214   35.090996
# 14  root_mean_squared_error        0.019810       0.068579   18.873964
# 15  root_mean_squared_error        0.015853       0.067916    5.592731
# 16  root_mean_squared_error        0.021210       0.042381   10.522391
# 17  root_mean_squared_error        0.016043       0.019713   18.768245
# 18  root_mean_squared_error        0.176708       1.355405   65.922980
# 19  root_mean_squared_error        0.066169       0.555493   16.488670
# 20  root_mean_squared_error        0.509420       4.665238  129.590239
# 21  root_mean_squared_error        0.437228       6.640042  272.786068
# 22  root_mean_squared_error        0.433991       4.346087  120.676458
# 23  root_mean_squared_error        0.414044       4.451797  134.970024
# 24  root_mean_squared_error        0.069123       0.230122   34.417057
# 25  root_mean_squared_error        0.066522       0.207060    3.196901
# 26  root_mean_squared_error        0.016272       0.117017   31.465871
# 27  root_mean_squared_error        0.079191       0.508532   15.074489
# 28  root_mean_squared_error        0.110582       1.026039   21.360901
# 29  root_mean_squared_error        0.416121       4.373778  122.242990
# 30  root_mean_squared_error        0.020238       0.081086   41.266009
# 31  root_mean_squared_error        0.458148       4.509132  134.851447
# 32  root_mean_squared_error        0.021156       0.050758   27.616780
# 33  root_mean_squared_error        0.606388       6.708118  184.356561
# 34  root_mean_squared_error        0.408394       4.367467  119.381859
# 35  root_mean_squared_error        0.455470       5.141728  341.675677
# 36  root_mean_squared_error        0.087851       0.403764   20.062854
# 37  root_mean_squared_error        0.421220       4.411313  120.663297
# 38  root_mean_squared_error        0.447999       4.406017  121.645733
# 39  root_mean_squared_error        0.425685      10.066061  181.876974
# 40  root_mean_squared_error        0.144770       0.350378   11.257249
# 41  root_mean_squared_error        0.416924       6.674906  135.814069
# 42  root_mean_squared_error        0.421343       6.223793  154.692866
# 43  root_mean_squared_error        0.105360       1.369978   77.233646
# 44  root_mean_squared_error        0.502500       4.526577  123.196760
# 45  root_mean_squared_error        0.066231       0.233417    2.932952
# 46  root_mean_squared_error        0.432326       4.428820  115.336204
# 47  root_mean_squared_error        0.225890       0.491216   17.775593
# 48  root_mean_squared_error        0.033515       0.212748    7.264923
# 49  root_mean_squared_error        0.509786       4.692259  150.228785
# 50  root_mean_squared_error        0.034881       0.100303    0.585525
# 51  root_mean_squared_error        0.540208       5.068714  140.244514
# 52  root_mean_squared_error        0.036534       0.390026    0.716976
# 53  root_mean_squared_error        0.430057       4.520178  115.679643
# 54  root_mean_squared_error        0.033427       1.132733    3.637772
# 55  root_mean_squared_error        0.431206       4.428584  116.649214
# 56  root_mean_squared_error        0.258712       0.377899   21.268899
# 57  root_mean_squared_error        0.096725       0.425636   28.790225
# 58  root_mean_squared_error        0.084529       0.512812   19.590129
#
#     pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  \
# 0                  0.010092                0.071676          19.192003
# 1                  0.015176                0.054548          13.865345
# 2                  0.023874                0.019966           6.274511
# 3                  0.104577                1.521532          33.906210
# 4                  0.015225                0.019963           8.749448
# 5                  0.070435                0.184525         411.395167
# 6                  0.050267                0.021719           4.466851
# 7                  0.051980                0.117294           2.823050
# 8                  0.013377                0.026856          13.351181
# 9                  0.038702                0.041755          51.695721
# 10                 0.038418                0.156039         188.935800
# 11                 0.017312                0.077648           8.226966
# 12                 0.008683                0.115010          24.459485
# 13                 0.087595                1.097214          35.090996
# 14                 0.019810                0.068579          18.873964
# 15                 0.015853                0.067916           5.592731
# 16                 0.021210                0.042381          10.522391
# 17                 0.016043                0.019713          18.768245
# 18                 0.001436                0.000373           0.018303
# 19                 0.066169                0.555493          16.488670
# 20                 0.112601                0.344876          14.981663
# 21                 0.040409                2.319680         158.177492
# 22                 0.037172                0.025725           6.067882
# 23                 0.017225                0.131435          20.361448
# 24                 0.069123                0.230122          34.417057
# 25                 0.066522                0.207060           3.196901
# 26                 0.016272                0.117017          31.465871
# 27                 0.079191                0.508532          15.074489
# 28                 0.110582                1.026039          21.360901
# 29                 0.019302                0.053416           7.634414
# 30                 0.020238                0.081086          41.266009
# 31                 0.061328                0.188770          20.242871
# 32                 0.021156                0.050758          27.616780
# 33                 0.001963                0.000378           0.010461
# 34                 0.011575                0.047105           4.773283
# 35                 0.058651                0.821366         227.067101
# 36                 0.087851                0.403764          20.062854
# 37                 0.024401                0.090951           6.054721
# 38                 0.051179                0.085655           7.037157
# 39                 0.028866                5.745699          67.268398
# 40                 0.144770                0.350378          11.257249
# 41                 0.020105                2.354545          21.205493
# 42                 0.024524                1.903431          40.084290
# 43                 0.105360                1.369978          77.233646
# 44                 0.105681                0.206215           8.588184
# 45                 0.066231                0.233417           2.932952
# 46                 0.035507                0.108458           0.727628
# 47                 0.225890                0.491216          17.775593
# 48                 0.033515                0.212748           7.264923
# 49                 0.112967                0.371897          35.620208
# 50                 0.034881                0.100303           0.585525
# 51                 0.143389                0.748352          25.635938
# 52                 0.036534                0.390026           0.716976
# 53                 0.033238                0.199816           1.071067
# 54                 0.033427                1.132733           3.637772
# 55                 0.034386                0.108222           2.040638
# 56                 0.258712                0.377899          21.268899
# 57                 0.096725                0.425636          28.790225
# 58                 0.084529                0.512812          19.590129
#
#     stack_level  can_infer  fit_order
# 0             1       True          9
# 1             1       True         23
# 2             1       True         15
# 3             1       True          8
# 4             1       True          1
# 5             1       True         17
# 6             1       True          7
# 7             1       True         25
# 8             1       True         12
# 9             1       True         21
# 10            1       True         14
# 11            1       True         36
# 12            1       True          2
# 13            1       True         37
# 14            1       True         38
# 15            1       True         27
# 16            1       True         19
# 17            1       True         33
# 18            2       True         39
# 19            1       True         34
# 20            2       True         47
# 21            2       True         53
# 22            2       True         51
# 23            2       True         48
# 24            1       True          6
# 25            1       True         31
# 26            1       True         10
# 27            1       True         24
# 28            1       True         28
# 29            2       True         41
# 30            1       True          4
# 31            2       True         45
# 32            1       True         29
# 33            3       True         59
# 34            2       True         40
# 35            2       True         56
# 36            1       True         13
# 37            2       True         54
# 38            2       True         46
# 39            2       True         49
# 40            1       True         26
# 41            2       True         58
# 42            2       True         43
# 43            1       True         11
# 44            2       True         52
# 45            1       True         22
# 46            2       True         57
# 47            1       True         16
# 48            1       True          3
# 49            2       True         50
# 50            1       True         18
# 51            2       True         55
# 52            1       True         32
# 53            2       True         44
# 54            1       True          5
# 55            2       True         42
# 56            1       True         20
# 57            1       True         35
# 58            1       True         30

# %% [markdown]
# # 2. Interpretability Analysis
#
# In this section, we will use SHAP (SHapley Additive exPlanations) to perform interpretability analysis on the trained model. This helps to identify important features and understand their impact on the model's predictions.

# %% [markdown]
# ## 2.1 AutoGluon Wrapper for SHAP
#
# This section defines a wrapper class for the AutoGluon predictor, making it compatible with SHAP for interpretability analysis. This part of the code is adapted from the work of AutoGluon developers.

# %%
# Initialize the SHAP environment
#shap.initjs()

#class AutogluonWrapper:
    #def __init__(self, predictor, feature_names):
        #self.ag_model = predictor
        #self.feature_names = feature_names
    
    #def predict(self, X):
        #if isinstance(X, pd.Series):
            #X = X.values.reshape(1,-1)
        # if not isinstance(X, pd.DataFrame):
            #X = pd.DataFrame(X, columns=self.feature_names)
        #return self.ag_model.predict(X)

# %%
# 初始化 SHAP 环境
shap.initjs()

# 你的特征列（1-140 列，问卷条目）
feature_names = data_SWB.columns[:140].tolist()

# 定义 AutoGluon 的包装器，兼容 SHAP
class AutogluonWrapper:
    def __init__(self, predictor, feature_names):
        self.ag_model = predictor
        self.feature_names = feature_names
    
    def predict(self, X):
        # 保证输入为 DataFrame
        if isinstance(X, pd.Series):
            X = X.values.reshape(1, -1)
        if not isinstance(X, pd.DataFrame):
            X = pd.DataFrame(X, columns=self.feature_names)
        return self.ag_model.predict(X)

# 初始化 wrapper（这里 predictor 是你训练好的 AutoGluon 模型）
wrapper = AutogluonWrapper(predictor, feature_names)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e,t,n={221:(e,t,n)=>{"use strict";var r=n(540);function a(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function i(){}var o={d:{f:i,r:function(){throw Error(a(522))},D:i,C:i,L:i,m:i,X:i,S:i,M:i},p:0,findDOMNode:null},u=Symbol.for("react.portal"),l=r.__CLIENT_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE;function s(e,t){return"font"===e?"":"string"==typeof t?"use-credentials"===t?t:"":void 0}t.__DOM_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE=o,t.createPortal=function(e,t){var n=2<arguments.length&&void 0!==arguments[2]?arguments[2]:null;if(!t||1!==t.nodeType&&9!==t.nodeType&&11!==t.nodeType)throw Error(a(299));return function(e,t,n){var r=3<arguments.length&&void 0!==arguments[3]?arguments[3]:null;return{$$typeof:u,key:null==r?null:""+r,children:e,containerInfo:t,implementation:n}}(e,t,null,n)},t.flushSync=function(e){var t=l.T,n=o.p;try{if(l.T=null,o.p=2,e)return e()}finally{l.T=t,o.p=n,o.d.f()}},t.preconnect=function(e,t){"string"==typeof e&&(t=t?"string"==typeof(t=t.crossOrigin)?"use-credentials"===t?t:"":void 0:null,o.d.C(e,t))},t.prefetchDNS=function(e){"string"==typeof e&&o.d.D(e)},t.preinit=function(e,t){if("string"==typeof e&&t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin),a="string"==typeof t.integrity?t.integrity:void 0,i="string"==typeof t.fetchPriority?t.fetchPriority:void 0;"style"===n?o.d.S(e,"string"==typeof t.precedence?t.precedence:void 0,{crossOrigin:r,integrity:a,fetchPriority:i}):"script"===n&&o.d.X(e,{crossOrigin:r,integrity:a,fetchPriority:i,nonce:"string"==typeof t.nonce?t.nonce:void 0})}},t.preinitModule=function(e,t){if("string"==typeof e)if("object"==typeof t&&null!==t){if(null==t.as||"script"===t.as){var n=s(t.as,t.crossOrigin);o.d.M(e,{crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0})}}else null==t&&o.d.M(e)},t.preload=function(e,t){if("string"==typeof e&&"object"==typeof t&&null!==t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin);o.d.L(e,n,{crossOrigin:r,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0,type:"string"==typeof t.type?t.type:void 0,fetchPriority:"string"==typeof t.fetchPriority?t.fetchPriority:void 0,referrerPolicy:"string"==typeof t.referrerPolicy?t.referrerPolicy:void 0,imageSrcSet:"string"==typeof t.imageSrcSet?t.imageSrcSet:void 0,imageSizes:"string"==typeof t.imageSizes?t.imageSizes:void 0,media:"string"==typeof t.media?t.media:void 0})}},t.preloadModule=function(e,t){if("string"==typeof e)if(t){var n=s(t.as,t.crossOrigin);o.d.m(e,{as:"string"==typeof t.as&&"script"!==t.as?t.as:void 0,crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0})}else o.d.m(e)},t.requestFormReset=function(e){o.d.r(e)},t.unstable_batchedUpdates=function(e,t){return e(t)},t.useFormState=function(e,t,n){return l.H.useFormState(e,t,n)},t.useFormStatus=function(){return l.H.useHostTransitionStatus()},t.version="19.1.0"},247:(e,t,n)=>{"use strict";var r=n(982),a=n(540),i=n(961);function o(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function u(e){return!(!e||1!==e.nodeType&&9!==e.nodeType&&11!==e.nodeType)}function l(e){var t=e,n=e;if(e.alternate)for(;t.return;)t=t.return;else{e=t;do{!!(4098&(t=e).flags)&&(n=t.return),e=t.return}while(e)}return 3===t.tag?n:null}function s(e){if(13===e.tag){var t=e.memoizedState;if(null===t&&n ...

# %% [markdown]
# **Using the Training Set vs. Test Set for SHAP Explainer**
#
# When creating a SHAP explainer, you have the option to use either the training set or the test set as the baseline. Using the training set as the baseline ensures that SHAP values are calculated based on the same data that the model was trained on, which helps in interpreting the model's behavior on familiar data and maintaining consistency with model training. However, it may not generalize well to new data and could reflect any biases present in the training data. On the other hand, using the test set as the baseline provides SHAP values that better represent the model's performance on unseen data, offering a less biased and more generalizable evaluation. It helps in understanding the model's behavior on real-world data but may lack the training context and could risk data leakage if not used properly. Choose the baseline based on your specific goals for interpretability analysis.

# %%
# Extract the features (X) and target variable (y)
#X_train = train_data.drop(columns=['CD-RISC'])# Replace with your target variable name
#y_train = train_data['CD-RISC']# Replace with your target variable name
#X_test = test_data.drop(columns=['CD-RISC'])# Replace with your target variable name
#y_test = test_data['CD-RISC']# Replace with your target variable name

# %%
# 提取特征（1-140列）和目标变量
# 从训练集 (train_data) 提取
# 理解模型在训练过程中学到了什么
X_train = train_data.iloc[:, :140]  
y_train = train_data['SWB']

# 从测试集 (test_data) 提取 
# 展示模型在真实应用场景（未见数据）中的解释力
X_test = test_data.iloc[:, :140]
y_test = test_data['SWB']

# %%
def print_accuracy(f):
    print("Root mean squared test error = {0}".format(np.sqrt(np.mean((f(X_test) - y_test)**2))))
rmse = print_accuracy(wrapper.predict)
# Out:
# Root mean squared test error = 0.9765426414701425

# %%
label = 'SWB'
feature_names = X_train.columns
train_data = X_train.copy()
train_data[label] = y_train
val_data = X_test.copy()

display(train_data.head())
# Out:
#      selfclarity_1  selfclarity_2  selfclarity_3  selfclarity_4  \
# 268       0.314527       0.458962       0.760821      -0.032856
# 73        0.314527      -0.326269       1.594575      -0.032856
# 289       1.369240       0.458962      -0.072933       0.793463
# 155      -1.794900      -1.896730      -0.906687      -0.859175
# 104       0.314527       1.244192       1.594575       0.793463
#
#      selfclarity_5  selfclarity_6  selfclarity_7  selfclarity_8  \
# 268       0.492151       0.306556      -0.456549       0.345348
# 73       -1.169271       0.306556       0.413315      -0.455158
# 289       0.492151       0.306556       0.413315       0.345348
# 155      -1.999982      -1.683093      -1.326413      -2.056170
# 104       1.322862       0.306556       1.283179       1.145854
#
#      selfclarity_9  selfclarity_10  ...    Social     Moral  ability_ALT_rt  \
# 268      -0.425004       -0.837878  ...  0.813375 -0.111875        0.055784
# 73       -1.231711        1.565844  ... -1.200049 -0.111875       -0.118096
# 289       0.381702        1.565844  ...  0.813375  0.991517       -0.932334
# 155      -1.231711       -1.639118  ... -0.394679 -0.111875       -1.452860
# 104       0.381702        1.565844  ...  0.008006 -0.111875       -0.573470
#
#      moral_ALT_rt  ability_ALT_d  ability_SRET_EW  moral_SRET_EW  \
# 268      3.472267       0.054921         0.764175       0.214579
# 73       2.622722       0.329820        -0.334838       0.648044
# 289     -1.688216      -0.912874         0.214668       0.214579
# 155      0.191061      -1.841509        -0.060085       0.648044
# 104      0.871062       1.175379         0.214668       0.214579
#
#      ability_SRET_rt  moral_SRET_rt       SWB
# 268         0.100002      -0.091383 -1.539937
# 73         -0.444233       0.155568 -0.024917
# 289         0.298583      -0.533714 -0.300375
# 155         0.338730      -0.211289 -0.851292
# 104        -0.483882      -0.425214 -1.264479
#
# [5 rows x 141 columns]

# %%
feature_names = predictor.feature_metadata.get_features()  # AutoGluon 记录的特征
X_train_summary = shap.kmeans(X_train, 10)
print("Baseline feature-values: \n", X_train_summary)
# Out:
# Baseline feature-values:
#  <shap.utils._legacy.DenseData object at 0x3bae0ab70>

# %%
ag_wrapper = AutogluonWrapper(predictor, feature_names)
print_accuracy(ag_wrapper.predict)

explainer = shap.KernelExplainer(ag_wrapper.predict, X_train_summary)
# Out:
# Root mean squared test error = 0.9765426414701425

# %%
# 初始化 AutogluonWrapper
ag_wrapper = AutogluonWrapper(predictor, feature_names)

# 构建 SHAP KernelExplainer
explainer = shap.KernelExplainer(ag_wrapper.predict, X_train_summary)

shap_values = explainer.shap_values(X_test[feature_names])

# 绘制 SHAP 总结图（只显示最重要的特征）
shap.summary_plot(shap_values, X_test[feature_names], plot_type="bar", max_display=20)
# Out:
#   0%|          | 0/101 [00:00<?, ?it/s]

# %%
ROW_INDEX = 0  
single_datapoint = X_train.iloc[[ROW_INDEX]]
single_prediction = ag_wrapper.predict(single_datapoint)

shap_values_single = explainer.shap_values(single_datapoint)
shap.force_plot(explainer.expected_value, shap_values_single, X_train.iloc[ROW_INDEX,:])
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# <div id='iZ62Y97ZDX2P39UYIXMA0'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.0541298501656868, "outValue": 0.14761723577976227, "link": "identity", "featureNames": ["selfclarity_1", "selfclarity_2", "selfclarity_3", "selfclarity_4", "selfclarity_5", "selfclarity_6", "selfclarity_7", "selfclarity_8", "selfclarity_9", "selfclarity_10", "selfclarity_11", "selfclarity_12", "LOT_1", "LOT_2", "LOT_3", "LOT_4", "LOT_5", "LOT_6", "IPC_1", "IPC_2", "IPC_3", "IPC_4", "IPC_5", "IPC_6", "IPC_7", "IPC_8", "ses_1", "ses_2", "ses_3", "ses_4", "ses_5", "ses_6", "ses_7", "ses_8", "ses_9", "ses_10", "coreself_1", "coreself_2", "coreself_3", "coreself_4", "coreself_5", "coreself_6", "coreself_7", "coreself_8", "coreself_9", "coreself_10", "NPI1", "NPI2", "NPI3", "NPI4", "NPI5", "NPI6", "NPI7", "NPI8", "NPI9", "NPI10", "NPI11", "NPI13", "NPI15", "hsns_1", "hsns_2", "hsns_3", "hsns_4", "hsns_5", "hsns_6", "hsns_7", "hsns_8", "hsns_9", "hsns_10", "MorIden_1", "MorIden_2", "MorIden_3", "MorIden_4", "MorIden_5", "MorIden_6", "MorIden_7", "MorIden_8", "MorIden_9", "MorIden_10", "moralSeImag_1", "moralSeImag_2", "moralSeImag_3", "moralSeImag_4", "moralSeImag_5", "moralSeImag_6", "moralSeImag_7", "moralSeImag_8", "moralSeImag_9", "sde_1", "sde_2", "sde_3", "sde_4", "sde_5", "sde_6", "sde_7", "sde_8", "sde_9", "sde_10", "sde_11", "sde_12", "sde_13", "sde_14", "sde_15", "sde_16", "sde_17", "sde_18", "sde_19", "sde_20", "IM_1", "IM_2", "IM_3", "IM_4", "IM_5", "IM_6", "IM_7", "IM_8", "IM_9", "IM_10", "IM_11", "IM_12", "IM_13", "IM_14", "IM_15", "IM_16", "IM_17", "IM_18", "IM_19", "IM_20", "Ability", "Attraction", "Wealth", "Social", "Moral", "ability_ALT_rt", "moral_ALT_rt", "ability_ALT_d", "ability_SRET_EW", "moral_SRET_EW", "ability_SRET_rt", "moral_SRET_rt"], "features": {"9": {"effect": -0.04878672632620161, "value": -0.837877628745331}, "57": {"effect": -0.06576296690480929, "value": 1.404422398267}, "66": {"effect": -0.03693619197850004, "value": -0.907888818520391}, "67": {"effect": -0.09347404413464672, "value": 0.887760777256466}, "74": {"effect": 0.058253136985134416, "value": -0.875991639810509}, "80": {"effect": -0.04366824132098666, "value": -1.8869802864439}, "86": {"effect": 0.05204476114607698, "value": -0.526594350519573}, "88": {"effect": -0.032201167559814836, "value": -0.930462648593042}, "120": {"effect": 0.0640018943679648, "value": -1.23233280633058}, "134": {"effect": 0.2400169313398584, "value": 3.47226721879207}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iZ62Y97ZDX2P39UYIXMA0')
#   );
# </script>

# %%
# Calculate SHAP values for the training data
# 计算训练集 SHAP
#shap_values = explainer.shap_values(X_train)
#shap.force_plot(explainer.expected_value, shap_values,X_train)

# 计算测试集 SHAP
shap_values = explainer.shap_values(X_test)
shap.force_plot(explainer.expected_value, shap_values, X_test)
# Out:
#   0%|          | 0/402 [00:00<?, ?it/s]
# <div id='iOWVPCK54T8VMCEHCRBB4'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["f(x)"], "baseValue": 0.06990429362402628, "link": "identity", "featureNames": ["selfclarity_1", "selfclarity_2", "selfclarity_3", "selfclarity_4", "selfclarity_5", "selfclarity_6", "selfclarity_7", "selfclarity_8", "selfclarity_9", "selfclarity_10", "selfclarity_11", "selfclarity_12", "LOT_1", "LOT_2", "LOT_3", "LOT_4", "LOT_5", "LOT_6", "IPC_1", "IPC_2", "IPC_3", "IPC_4", "IPC_5", "IPC_6", "IPC_7", "IPC_8", "ses_1", "ses_2", "ses_3", "ses_4", "ses_5", "ses_6", "ses_7", "ses_8", "ses_9", "ses_10", "coreself_1", "coreself_2", "coreself_3", "coreself_4", "coreself_5", "coreself_6", "co
.23166296738509}, "31": {"effect": 0.0, "value": -0.353936830550823}, "32": {"effect": 0.0, "value": -0.221561947547169}, "33": {"effect": 0.0, "value": -1.04997448991398}, "34": {"effect": -0.02925076258172799, "value": 0.79754736213162}, "35": {"effect": 0.0, "value": 0.741663379167847}, "36": {"effect": 0.0, "value": 0.0386802871145531}, "37": {"effect": 0.0, "value": 0.469182663280274}, "38": {"effect": 0.0, "value": 0.745248858745497}, "39": {"effect": 0.0, "value": 0.218681057487635}, "40": {"effect": 0.0, "value": 0.420539059450193}, "41": {"effect": 0.0, "value ...

# %%
# Generate a SHAP summary plot
# 训练集总结图
#shap.summary_plot(shap_values, X_train[feature_names])
# 测试集总结图
shap.summary_plot(shap_values, X_test[feature_names])

# %%
# Generate a SHAP dependence plot for the feature "SES7"
# 计算训练集 SHAP，绘制plot
#shap_values = explainer.shap_values(X_train[feature_names])
#shap.dependence_plot("NPI4", shap_values, X_train[feature_names])

# 计算测试集 SHAP，绘制plot
shap_values = explainer.shap_values(X_test[feature_names])
shap.dependence_plot("NPI1", shap_values, X_test[feature_names])
# Out:
#   0%|          | 0/101 [00:00<?, ?it/s]

# %% [markdown]
# # 3. Exploratory Factor Analysis (EFA)
#
# In this section, we will perform Exploratory Factor Analysis (EFA) to uncover the underlying factor structure in the data. EFA helps in identifying the latent variables that explain the patterns in the observed variables.

# %% [markdown]
# ## 3.1 Preparing Data for EFA
#
# To perform Exploratory Factor Analysis (EFA), we need to calculate the importance of variables and exclude those that do not meet a certain threshold. In this case, we will include variables that contribute up to 80% of the total importance and exclude demographic variables.

# %%
# Calculate cumulative importance
shap_values_train = np.array(shap_values)  
feature_importance = np.mean(np.abs(shap_values_train), axis=0)
feature_importance_df = pd.DataFrame({
    'feature': X_train.columns,
    'importance': feature_importance
}).sort_values(by='importance', ascending=False)
feature_importance_df['cumulative_importance'] = feature_importance_df['importance'].cumsum()
feature_importance_df['cumulative_importance'] /= feature_importance_df['importance'].sum()

# %%
# Determine the number of features to reach 80% importance
threshold = 0.8
num_important_features = (feature_importance_df['cumulative_importance'] <= threshold).sum()
print(f"Number of features to reach {threshold*100}% of importance: {num_important_features}")
# Out:
# Number of features to reach 80.0% of importance: 20

# %%
# Printing the Names and Importance of the Top 24 Features
top_features = feature_importance_df.head(num_important_features)
important_feature_names = top_features['feature'].tolist()
print(top_features[['feature', 'importance']])
# Out:
#              feature  importance
# 134     moral_ALT_rt    0.030637
# 111             IM_4    0.028652
# 74         MorIden_6    0.022821
# 139    moral_SRET_rt    0.021558
# 90             sde_3    0.015181
# 43        coreself_8    0.014224
# 71         MorIden_3    0.012455
# 136  ability_SRET_EW    0.012326
# 42        coreself_7    0.012291
# 133   ability_ALT_rt    0.010707
# 95             sde_8    0.010219
# 123            IM_16    0.008990
# 109             IM_2    0.008249
# 115             IM_8    0.007584
# 86     moralSeImag_8    0.006323
# 19             IPC_2    0.005878
# 113             IM_6    0.005393
# 118            IM_11    0.005163
# 132            Moral    0.005035
# 124            IM_17    0.004915

# %% [markdown]
# # Printing the Names and Importance of the Top Features
# top_features = feature_importance_df.head(num_important_features)
# important_feature_names = top_features['feature'].tolist()
# print(top_features[['feature', 'importance']])

# %%
# Exclude demographic variables
#variables_to_remove = ['Gender_1.0', 'Gender_2.0','Daily online duration']
#important_feature_names = [feature for feature in important_feature_names if feature not in variables_to_remove]
important_data = data_SWB[important_feature_names]

# %% [markdown]
# ## 3.2 Parallel Analysis to Determine the Number of Factors
#
# To determine the appropriate number of factors for Exploratory Factor Analysis (EFA), we perform parallel analysis. This method compares the eigenvalues from the actual data with those from randomly generated data.

# %% [markdown]
# **Bartlett's Test of Sphericity:** This test assesses whether the correlation matrix is an identity matrix, which would indicate that variables are unrelated. A significant result (p-value < 0.05) suggests that the correlation matrix is not an identity matrix, implying that the data is suitable for factor analysis.
#
# **KMO Test:** The KMO test evaluates the adequacy of the correlation matrix for factor analysis. It measures the proportion of variance among variables that might be common variance. The KMO statistic ranges from 0 to 1, with values closer to 1 indicating that the data is suitable for factor analysis.

# %%
def calculate_rmsea(chi_square, dof, n):
    rmsea = np.sqrt((chi_square - dof) / (dof * (n - 1)))
    return rmsea

def calculate_tli(chi_square, dof, chi_square_null, dof_null):
    tli = 1 - (chi_square / dof) / (chi_square_null / dof_null)
    return tli

# Bartlett's Test of Sphericity
# To ensure that the variables are sufficiently correlated for factor analysis, we perform Bartlett's Test of Sphericity. This test checks whether the correlation matrix is significantly different from an identity matrix.
bartlett_test, p_value = calculate_bartlett_sphericity(important_data)
print(f"Bartlett's Test: Chi-square = {bartlett_test}, p-value = {p_value}")

# Perform the Kaiser-Meyer-Olkin (KMO) Test
kmo_all, kmo_model = calculate_kmo(important_data)
print(f"KMO Test: {kmo_model}")
# Out:
# Bartlett's Test: Chi-square = 2920.8981094835494, p-value = 0.0
# KMO Test: 0.8782862651243469

# %% [markdown]
# **Parallel Analysis (Simplified Implementation)**
#
# Determines optimal number of factors by comparing eigenvalues from actual data with those derived from random data using PCA, calculating mean random eigenvalues (mean_random_eigenvalues) as a threshold for component retention

# %%
def parallel_analysis(data_SWB, n_iterations=1000):
    n_samples, n_features = data_SWB.shape
    random_eigenvalues = np.zeros((n_iterations, n_features))
    for i in range(n_iterations):
        random_data = np.random.normal(size=data_SWB.shape)
        pca = PCA()
        pca.fit(random_data)
        random_eigenvalues[i, :] = pca.explained_variance_
    mean_random_eigenvalues = random_eigenvalues.mean(axis=0)
    return mean_random_eigenvalues

pca = PCA()
pca.fit(important_data)
eigenvalues = pca.explained_variance_
mean_random_eigenvalues = parallel_analysis(important_data)
num_factors = np.sum(eigenvalues > mean_random_eigenvalues)
print(f"Number of factors to retain based on parallel analysis: {num_factors}")
# Out:
# Number of factors to retain based on parallel analysis: 3

# %%
# Create the FactorAnalyzer object, specifying the number of factors to retain
fa = FactorAnalyzer(n_factors=num_factors, rotation='varimax')
fa.fit(important_data)
# Out:
# FactorAnalyzer(rotation='varimax', rotation_kwargs={})

# %%
# Get the factor loadings
loadings = fa.loadings_
variable_names = important_data.columns.tolist()
num_factors = loadings.shape[1]
factor_names = [f'Factor{i+1}' for i in range(num_factors)]
factor_loadings_df = pd.DataFrame(loadings, index=variable_names,columns=factor_names)
# Remove loadings with absolute values less than 0.3
factor_loadings_df = factor_loadings_df.where(abs(factor_loadings_df) >= 0.3, '')
print("Factor Loadings: \n", factor_loadings_df)
# Out:
# Factor Loadings:
#                    Factor1   Factor2   Factor3
# moral_ALT_rt
# IM_4             0.685729
# MorIden_6        0.420954
# moral_SRET_rt
# sde_3            0.546603
# coreself_8       0.497734  0.458512  0.542357
# MorIden_3                  0.369322
# ability_SRET_EW            0.651305
# coreself_7       0.427484  0.458317  0.543288
# ability_ALT_rt
# sde_8
# IM_16            0.633419  0.343448
# IM_2             0.785388
# IM_8             0.412895
# moralSeImag_8              0.627487
# IPC_2                       0.39575
# IM_6             0.558079  0.375957
# IM_11            0.523076   0.32198
# Moral            0.344984  0.571383
# IM_17            0.591056

# %%
# 假设你的 DataFrame 变量名是 factor_loadings
factor_loadings_df.to_csv("SWB_factor_loadings.csv", index=False)

# %%
#Evaluation of the Factor Analysis Model
# Sample and variable counts
n = important_data.shape[0]
p = important_data.shape[1]

# Calculate correlation matrix
corr_matrix = np.corrcoef(important_data, rowvar=False)

# Get loadings and uniquenesses
loadings = fa.loadings_
uniquenesses = 1 - np.sum(loadings**2, axis=1)

# Calculate model-implied correlation matrix
model_corr = loadings @ loadings.T
np.fill_diagonal(model_corr, model_corr.diagonal() + uniquenesses)

# Calculate chi-square using maximum likelihood method
log_det_corr = np.log(np.linalg.det(corr_matrix))
log_det_model = np.log(np.linalg.det(model_corr))
trace = np.trace(corr_matrix @ np.linalg.inv(model_corr)) - p
chi_square = (n - 1) * (log_det_model + trace - log_det_corr)

# Calculate degrees of freedom
dof = (p * (p + 1)) / 2 - (p * num_factors + p - (num_factors * (num_factors - 1)) / 2)

# Calculate null model chi-square
diag_corr = np.diag(np.diag(corr_matrix))
log_det_diag = np.log(np.linalg.det(diag_corr))
trace_null = np.trace(corr_matrix @ np.linalg.inv(diag_corr)) - p
chi_square_null = (n - 1) * (log_det_diag + trace_null - log_det_corr)
dof_null = p * (p - 1) / 2

# Calculate RMSEA 
rmsea = np.sqrt(max(0, (chi_square - dof) / (dof * (n - 1))))

# Calculate TLI
tli = ((chi_square_null / dof_null) - (chi_square / dof)) / ((chi_square_null / dof_null) - 1)

print(f"RMSEA: {rmsea:.4f}")
print(f"TLI: {tli:.4f}")
print(f"Chi-square: {chi_square:.4f}, df: {dof:.4f}")
print(f"p-value: {1 - stats.chi2.cdf(chi_square, dof):.4f}")
# Out:
# RMSEA: 0.0480
# TLI: 0.9207
# Chi-square: 286.9787, df: 133.0000
# p-value: 0.0000

# %% [markdown]
# # # Extra Method 1: R and Python Interaction for Factor Analysis (Recommended)
#
# The code utilizes the rpy2 interface to access R's psych package, preserving R's professional advantages in psychological statistical analysis while incorporating Python's flexibility and data processing capabilities. Users only need to provide appropriately formatted data files, and the system automatically handles R environment configuration, necessary package installation, data conversion, statistical analysis, and results presentation.
#
# The framework supports multiple factor extraction methods and rotation techniques, while providing comprehensive model fit indicators such as RMSEA, TLI, and BIC. This integration delivers a powerful yet user-friendly solution for researchers and practitioners working with psychometric data, combining the best statistical tools from both programming ecosystems.

# %%
# Save the Data to CSV File
important_data.to_csv("factor_analysis_data_r.csv", index=False)
print("Factor analysis data successfully exported to factor_analysis_data.csv")
# Out:
# Factor analysis data successfully exported to factor_analysis_data.csv

# %%
# Set up R environment
import os
os.environ['R_HOME'] = r'/Library/Frameworks/R.framework/Versions/4.4.1/Resources'  # Use your correct R installation path
import rpy2.robjects as ro
from rpy2.robjects import pandas2ri
from rpy2.robjects.packages import importr
from rpy2.robjects.vectors import StrVector
from rpy2.robjects.conversion import localconverter

# Activate pandas to R data conversion
#pandas2ri.activate()
import rpy2.robjects.pandas2ri as pandas2ri
# 读取数据
df = pd.read_csv("/Users/sunxinru/Desktop/ML/Data/ML_pre.csv")

# 在 with 语句里完成 DataFrame -> R data.frame 的转换
#with localconverter(ro.default_converter + pandas2ri.converter):
    #r_df = ro.conversion.py2rpy(df)

def run_parallel_analysis(data_path, fa_method="both", n_iter=100, fm="ml"):
    """
    Run parallel analysis on the data with the specified method.
    
    Parameters:
    -----------
    data_path : str
        Path to the CSV file containing the data.
    fa_method : str
        Method for parallel analysis. Options: "pc", "fa", or "both".
    n_iter : int
        Number of iterations for simulation.
    fm : str
        Factor extraction method. Options: "ml", "minres", "pa", etc.
        
    Returns:
    --------
    dict
        A dictionary containing the analysis results.
    """
    try:
        # Import R base packages
        base = importr('base')
        utils = importr('utils')
        psych = importr('psych')
        
        # Read data
        df = pd.read_csv(data_path)
        print(f"Data successfully loaded: {df.shape[0]} rows and {df.shape[1]} columns")
        
        # Convert data to R dataframe
        with localconverter(ro.default_converter + pandas2ri.converter):
            r_df = ro.conversion.py2rpy(df)
        
        # Execute parallel analysis
        print(f"Starting parallel analysis with method: {fa_method}...")
        ro.r('set.seed(123)')

        r_setup = """
        pdf(file=NULL) 
        """
        ro.r(r_setup)

        # Use R string to execute parallel analysis
        r_code = f"""
        parallel_result <- function(df) {{
          library(psych)
          result <- fa.parallel(df, fa="{fa_method}", fm="{fm}", n.iter={n_iter}, sim=TRUE, show=FALSE)
          dev.off()  
          return(result)
        }}
        """
        ro.r(r_code)
        parallel_result = ro.r('parallel_result')(r_df)
        
        # Extract results based on analysis method
        result = {}
        
        if fa_method in ["fa", "both"]:
            n_factors = parallel_result.rx2('nfact')[0]
            result["n_factors"] = n_factors
            print(f"Suggested number of factors: {n_factors}")
        
        if fa_method in ["pc", "both"]:
            n_components = parallel_result.rx2('ncomp')[0]
            result["n_components"] = n_components
            print(f"Suggested number of components: {n_components}")
        
        # Extract relevant eigenvalues based on method
        r_extract_values = f"""
        extract_values <- function(result) {{
          list(
            observed = if("{fa_method}" == "pc") result$pc.values else if("{fa_method}" == "fa") result$fa.values else NULL,
            simulated = if("{fa_method}" == "pc") {{
              if(is.matrix(result$pc.sim)) colMeans(result$pc.sim) else result$pc.simr
            }} else if("{fa_method}" == "fa") {{
              if(is.matrix(result$fa.sim)) colMeans(result$fa.sim) else result$fa.simr
            }} else NULL,
            fa_observed = if("{fa_method}" == "both") result$fa.values else NULL,
            fa_simulated = if("{fa_method}" == "both") {{
              if(is.matrix(result$fa.sim)) colMeans(result$fa.sim) else result$fa.simr
            }} else NULL,
            pc_observed = if("{fa_method}" == "both") result$pc.values else NULL,
            pc_simulated = if("{fa_method}" == "both") {{
              if(is.matrix(result$pc.sim)) colMeans(result$pc.sim) else result$pc.simr
            }} else NULL
          )
        }}
        """
        ro.r(r_extract_values)
        extracted_values = ro.r('extract_values')(parallel_result)
        
        # Convert R values to Python
        with localconverter(ro.default_converter + pandas2ri.converter):
            if fa_method in ["pc", "fa"]:
                observed = ro.conversion.rpy2py(extracted_values.rx2('observed'))
                simulated = ro.conversion.rpy2py(extracted_values.rx2('simulated'))
                result["observed"] = observed
                result["simulated"] = simulated
            elif fa_method == "both":
                fa_observed = ro.conversion.rpy2py(extracted_values.rx2('fa_observed'))
                fa_simulated = ro.conversion.rpy2py(extracted_values.rx2('fa_simulated'))
                pc_observed = ro.conversion.rpy2py(extracted_values.rx2('pc_observed'))
                pc_simulated = ro.conversion.rpy2py(extracted_values.rx2('pc_simulated'))
                result["fa_observed"] = fa_observed
                result["fa_simulated"] = fa_simulated
                result["pc_observed"] = pc_observed
                result["pc_simulated"] = pc_simulated
        
        # Save suggested factor numbers to file
        #with open(f'suggested_factors_{fa_method}.txt', 'w') as f:
        #    if fa_method in ["fa", "both"]:
        #        f.write(f"Suggested number of factors: {n_factors}\n")
        #    if fa_method in ["pc", "both"]:
        #        f.write(f"Suggested number of components: {n_components}")
        
       # print(f"Parallel analysis completed with method '{fa_method}' and results saved to text file.")
        
        return result
    
    except Exception as e:
        print(f"An error occurred: {str(e)}")
        import traceback
        traceback.print_exc()
        return None

# Example usage
if __name__ == "__main__":
    # Change this to the desired method: "pc", "fa", or "both"
    analysis_method = "both"
    
    # Run the analysis
    result = run_parallel_analysis("factor_analysis_data_r.csv", 
                                  fa_method=analysis_method,
                                  n_iter=100, 
                                  fm="pa")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[87], line 5
#       3 os.environ['R_HOME'] = r'/Library/Frameworks/R.framework/Versions/4.4.1/Resources'  # Use your correct R installation path
#       4 import rpy2.robjects as ro
# ----> 5 from rpy2.robjects import pandas2ri
#       6 from rpy2.robjects.packages import importr
#       7 from rpy2.robjects.vectors import StrVector
#
# ImportError: cannot import name 'pandas2ri' from 'rpy2.robjects' (unknown location)

# %%
try:
    # Import R base packages
    base = importr('base')
    utils = importr('utils')
    stats = importr('stats')
    
    # Check and install necessary R packages
    package_names = ['psych', 'lavaan']
    utils.chooseCRANmirror(ind=1)  # Select CRAN mirror
    
    # Check if packages are installed, install if not
    names_to_install = [x for x in package_names if not ro.packages.isinstalled(x)]
    if len(names_to_install) > 0:
        print(f"Installing R packages: {', '.join(names_to_install)}")
        utils.install_packages(StrVector(names_to_install))
    
    # Import required R packages
    psych = importr('psych')
    lavaan = importr('lavaan')
    
    # Read data
    # Assuming your data is stored in a CSV file
    try:
        data_path = "factor_analysis_data.csv"  # Ensure this file exists
        df = pd.read_csv(data_path)
        print(f"Data successfully loaded: {df.shape[0]} rows and {df.shape[1]} columns")
        
        # Convert pandas dataframe to R dataframe
        with localconverter(ro.default_converter + pandas2ri.converter):
            r_df = ro.conversion.py2rpy(df)
        
        # Execute factor analysis
        print("Starting factor analysis...")
        fa_result = psych.fa(r_df, nfactors=5, rotate="varimax")
        
        # Extract results
        # Get fit indices
        rmsea = fa_result.rx2('RMSEA')[0]
        tli = fa_result.rx2('TLI')[0] if 'TLI' in fa_result.names else None
        bic = fa_result.rx2('BIC')[0] if 'BIC' in fa_result.names else None
        chi_square = fa_result.rx2('chi')[0] if 'chi' in fa_result.names else None
        df_value = fa_result.rx2('dof')[0] if 'dof' in fa_result.names else None
        p_value = fa_result.rx2('PVAL')[0] if 'PVAL' in fa_result.names else None
        
        # Create fit indices dataframe
        fit_indices = pd.DataFrame({
            'RMSEA': [rmsea],
            'TLI': [tli],
            'BIC': [bic],
            'chi_square': [chi_square],
            'df': [df_value],
            'p_value': [p_value]
        })
        
        # Get factor loadings
        loadings_r = fa_result.rx2('loadings')
        
        # Convert R matrix to pandas dataframe
        with localconverter(ro.default_converter + pandas2ri.converter):
            loadings_matrix = ro.conversion.rpy2py(loadings_r)
        
        # Create pandas dataframe from R matrix
        column_names = [f"Factor{i+1}" for i in range(loadings_matrix.shape[1])]
        loadings_df = pd.DataFrame(
            loadings_matrix, 
            index=df.columns, 
            columns=column_names
        )
        
        # Save results to CSV files (if needed)
        #fit_indices.to_csv("fit_indices.csv", index=False)
        #loadings_df.to_csv("factor_loadings.csv")
        
        # Display results
        print("\nFit indices:")
        print(fit_indices)
        print("\nFactor loadings:")
        print(loadings_df)
        
    except FileNotFoundError:
        print(f"Error: Data file '{data_path}' not found, please check the file path")
    except Exception as e:
        print(f"Error processing data: {str(e)}")

except ImportError as e:
    print(f"R package import error: {str(e)}")
    print("Please ensure R and required R packages are correctly installed")
except Exception as e:
    print(f"An error occurred: {str(e)}")
# Out:
# R callback write-console: Warning:
# R callback write-console:  failed to download mirrors file (internet routines cannot be loaded); using local file '/Library/Frameworks/R.framework/Resources/doc/CRAN_mirrors.csv'
# Error: Data file 'factor_analysis_data.csv' not found, please check the file path

# %% [markdown]
# ### Additional Method 2: Parallel Analysis Package
#
# The parallel-analysis package offers a comprehensive implementation with enhanced functionality.
# However, this Python package is published on the test channel. It is recommended to use Additional Method 1 for more refined control.
#
# Based on package: https://test.pypi.org/project/parallel-analysis/

# %%
from parallel_analysis import parallel_analysis

# Perform parallel analysis on the data (using both PCA and FA methods)
results = parallel_analysis(
    important_data,
    n_iterations=100,   # Set 100 iterations for more stable results
    percentile=95,      # Use the 95th percentile as the threshold
    random_state=123,   # Set random seed to ensure reproducibility
    fa="both",          # Use both PCA and FA methods for analysis
    fm="pa",            # Use principal axis factor extraction method
)

# Print PCA results
print("=== PCA Parallel Analysis Results ===")
print(f"Number of components suggested to retain: {results['pc']['n_components']}")

# Print FA results
if 'fa' in results:
    print("\n=== FA Parallel Analysis Results ===")
    print(f"Number of factors suggested to retain: {results['fa']['n_components']}")
# Out:
# === PCA Parallel Analysis Results ===
# Number of components suggested to retain: 2
#
# === FA Parallel Analysis Results ===
# Number of factors suggested to retain: 3
